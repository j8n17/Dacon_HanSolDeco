# %%
import numpy as np
import pandas as pd
import re
import json
from utils import load_ollama, prompt_test, run_ollama, process_dataframe_in_chunks
from tqdm import tqdm
tqdm.pandas()

test_csv_path = '../data/test_07.csv'
rag_result_path = '../data/rag_result_05.csv'

test_df = pd.read_csv(test_csv_path, encoding='utf-8-sig')
rag_result_df = pd.read_csv(rag_result_path, encoding='utf-8-sig')

# %%
test_df = test_df.drop(columns=['isvalidllm_answer_1', 'isvalidllm_answer_2', 'isvalidllm_answer_3'])

# %% [markdown]
# ### 임베딩 벡터 준비

# %%
from sentence_transformers import SentenceTransformer

# 모델 불러오기
embedding_model_name = "jhgan/ko-sbert-sts"
embedding = SentenceTransformer(embedding_model_name)
answer_cols = sorted([col for col in test_df.columns if 'llm_answer' in col])

def compute_answer_embeddings_for_row(row, answer_cols):
    # 각 행에서 1번부터 25번까지의 문장을 리스트로 모읍니다.
    sentences = [row[col] for col in answer_cols]
    # 25개의 문장에 대해 임베딩을 계산합니다. (반환: (25, embedding_dim))
    embeddings = embedding.encode(sentences)
    return embeddings

# 각 행에 대해 임베딩을 계산하고, Series로 반환된 결과를 ndarray로 스택합니다.
answer_embeddings = test_df.apply(lambda x: compute_answer_embeddings_for_row(x, answer_cols), axis=1)
answer_ndarray = np.stack(answer_embeddings.to_numpy())

print("answer_ndarray shape:", answer_ndarray.shape)
# Out:
# answer_ndarray shape: (964, 3, 768)

# %%
rag_gt_cols = sorted([col for col in rag_result_df.columns if 'rerank_gt' in col])

def compute_gt_embeddings_for_row(row, rag_gt_cols):
    # 각 행에서 1번부터 25번까지의 문장을 리스트로 모읍니다.
    sentences = [row[col] for col in rag_gt_cols]
    # 25개의 문장에 대해 임베딩을 계산합니다. (반환: (25, embedding_dim))
    embeddings = embedding.encode(sentences)
    return embeddings

# 각 행에 대해 임베딩을 계산하고, Series로 반환된 결과를 ndarray로 스택합니다.
ground_truth_embeddings = rag_result_df.apply(lambda x: compute_gt_embeddings_for_row(x, rag_gt_cols), axis=1)
ground_truth_ndarray = np.stack(ground_truth_embeddings.to_numpy())

print("ground_truth_ndarray shape:", ground_truth_ndarray.shape)
# Out:
# ground_truth_ndarray shape: (964, 25, 768)

# %% [markdown]
# ### 코사인 유사도 계산 및 argmax

# %%
def best_prediction_index(predictions: np.ndarray, ground_truth: np.ndarray) -> list:
    """
    주어진 예측과 정답 임베딩 벡터들 간의 코사인 유사도의 평균이 가장 높은 예측의 인덱스를 반환합니다.
    
    인자:
        predictions: np.ndarray, shape (N, p, d)
            - N: 데이터 개수
            - p: 각 데이터당 예측 임베딩 개수
            - d: 임베딩 벡터의 차원
        ground_truth: np.ndarray, shape (N, t, d)
            - N: 데이터 개수
            - t: 각 데이터당 정답 임베딩 개수
            - d: 임베딩 벡터의 차원
    
    반환:
        best_indices: list of int
            - 각 데이터별로 예측 중 코사인 유사도 평균이 가장 높은 예측의 인덱스를 담은 리스트
    """
    # 예측 및 정답 벡터의 노름(norm)을 계산합니다.
    pred_norms = np.linalg.norm(predictions, axis=2)  # shape: (N, p)
    gt_norms = np.linalg.norm(ground_truth, axis=2)     # shape: (N, t)
    
    # 배치별로 각 예측 벡터와 정답 벡터 간의 내적을 계산합니다.
    # np.einsum을 사용하여 (N, p, t) 형태의 결과를 얻습니다.
    dot_products = np.einsum('ipd,itd->ipt', predictions, ground_truth)  # shape: (N, p, t)
    
    # 예측과 정답 벡터의 노름을 외적하여 각 예측-정답 쌍에 대한 분모를 구성합니다.
    norms = pred_norms[:, :, None] * gt_norms[:, None, :]
    
    # 0으로 나누는 경우를 방지하기 위해 작은 값을 더해줍니다.
    epsilon = 1e-8
    cosine_similarities = dot_products / (norms + epsilon)
    
    # 각 예측 벡터에 대해 t개의 정답 벡터와의 코사인 유사도의 평균을 구합니다.
    avg_cosine_sim = np.mean(cosine_similarities, axis=2)  # shape: (N, p)
    
    # 각 데이터에서 평균 코사인 유사도가 가장 높은 예측의 인덱스를 찾습니다.
    best_indices = np.argmax(avg_cosine_sim, axis=1)
    
    return best_indices.tolist()

# %%
test_df['best_index'] = best_prediction_index(answer_ndarray, ground_truth_ndarray)

# %% [markdown]
# ### best_index로 정답 문장 선택

# %%
def choose_answer(row):
    idx = row['best_index']
    return row[f'llm_answer_{idx+1}']

# %%
answers = test_df.apply(choose_answer, axis=1).tolist()

# %%
test_df
# Out:
#       id                                        description  \
# 0      0  타설작업 중 콘크리트펌프 관련 부딪힘 및 전도 사고 (펌프카 아웃트리거 바닥 고임목...
# 1      1  절단작업 중 공구류 관련 절단, 베임 사고 (작업자의 불안전한 행동(숫돌 측면 사용...
# 2      2  이동 중 떨어짐 사고 (작업자가 작업을 위해 이동 중 전방을 주시하지 않아 발을 헛...
# 3      3       자재 관련 넘어짐(물체에 걸림) 사고 (작업 발판 위 벽돌 잔재를 밟고 넘어짐)
# 4      4   해체작업 중 떨어짐 사고 (점심식사를 위한 이동시 작업자 부주의로 인한 추락사고 발생)
# ..   ...                                                ...
# 959  959       마감작업 중 건물 관련 부딪힘 사고 (약한 석재가 자연 파단하여 늑골 골절 됨)
# 960  960     조립작업 중 철망 관련 넘어짐 사고 (근로자가 작업 중 이동가능한 통로 확보 미흡)
# 961  961  타설작업 중 콘크리트믹서트럭 관련 끼임 사고 (작업자가 믹서트럭 슈트아래로 불안전하...
# 962  962  청소작업 중 자재 관련 사고 (깨진타일을 손으로 주워 마대자루에 넣을려고 하던 중 ...
# 963  963  절단작업 중 공구류 관련 절단, 베임 사고 (2024년 11월 6일 9시경 재해자가...
#
#                             correct_description_prompt  \
# 0    당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 1    당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 2    당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 3    당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 4    당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# ..                                                 ...
# 959  당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 960  당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 961  당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 962  당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
# 963  당신은 맞춤법 수정 전문가입니다. 제공될 문장의 맞춤법을 수정하되, 형식을 유지하고...
#
#                                    correct_description category_exists  \
# 0    타설 작업 중 콘크리트 펌프 관련 부딪힘 및 전도 사고(펌프카 아웃트리거 바닥 고임...               Y
# 1    절단 작업 중 공구류 관련 절단, 베임 사고 (작업자의 불안전한 행동(숫돌 측면 사...               Y
# 2    이동 중 떨어짐 사고 (작업자가 작업을 위해 이동 중 전방을 주시하지 않아 발을 헛...               Y
# 3          자재 관련 넘어짐(물체에 걸림) 사고(작업 발판 위 벽돌 잔재를 밟고 넘어짐)               Y
# 4    해체작업 중 떨어짐 사고(점심 식사 시간 이동 중 작업자 부주의로 인한 추락 사고 발생)               Y
# ..                                                 ...             ...
# 959        마감 작업 중 건물 관련 충돌 사고 (약한 석재가 자연 파단으로 늑골 골절됨)               Y
# 960     조립작업 중 철망 관련 넘어짐 사고(근로자가 작업 중 이동 가능한 통로 확보 미흡)               Y
# 961  타설작업 중 콘크리트 믹서트럭 관련 끼임 사고 (작업자가 믹서트럭 슈트 아래로 불안...               Y
# 962  청소 작업 중 자재 관련 사고(깨진 타일을 손으로 모아 마대자루에 담으려다 파편이 ...               Y
# 963  절단 작업 중 공구류 관련 절단, 베임 사고 (2024년 11월 6일 9시경 재해자...               Y
#
#                                     structuring_prompt  \
# 0    한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 1    한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 2    한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 3    한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 4    한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# ..                                                 ...
# 959  한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 960  한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 961  한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 962  한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
# 963  한국 건설 공사 안전 사고 관련 문장을 언어 모델에 사용하기 위해 전처리하려 합니다...
#
#                                        structured_json  \
# 0    ```json\n{\n  "발생 배경": "타설 작업 중 콘크리트 펌프 사용",\n...
# 1    ```json\n{\n  "발생 배경": "절단 작업 중",\n  "사고 종류": ...
# 2    ```json\n{\n  "발생 배경": "작업자가 작업을 위해 이동 중",\n  ...
# 3    ```json\n{\n  "발생 배경": "작업 발판 위 벽돌 잔재",\n  "사고...
# 4    ```json\n{\n  "발생 배경": "해체 작업 중",\n  "사고 종류": ...
# ..                                                 ...
# 959  ```json\n{\n  "발생 배경": "마감 작업 중",\n  "사고 종류": ...
# 960  ```json\n{\n  "발생 배경": "조립작업 중",\n  "사고 종류": "...
# 961  ```json\n{\n  "발생 배경": "타설작업 중",\n  "사고 종류": "...
# 962  ```json\n{\n  "발생 배경": "청소 작업 중",\n  "사고 종류": ...
# 963  ```json\n{\n  "발생 배경": "절단 작업 중 각도 절단기 이용",\n ...
#
#                                 structured_description  \
# 0    발생 배경: 타설 작업 중 콘크리트 펌프 사용, 사고 종류: 콘크리트 펌프 관련 부...
# 1    발생 배경: 절단 작업 중, 사고 종류: 공구류 관련 절단, 베임 사고, 사고 원인...
# 2    발생 배경: 작업자가 작업을 위해 이동 중, 사고 종류: 이동 중 떨어짐 사고, 사...
# 3    발생 배경: 작업 발판 위 벽돌 잔재, 사고 종류: 넘어짐 (물체에 걸림), 사고 ...
# 4    발생 배경: 해체 작업 중, 사고 종류: 떨어짐 사고 (점심 식사 시간 이동 중 작...
# ..                                                 ...
# 959  발생 배경: 마감 작업 중, 사고 종류: 건물 관련 충돌 사고, 사고 원인: 약한 ...
# 960  발생 배경: 조립작업 중, 사고 종류: 철망 관련 넘어짐 사고, 사고 원인: 근로자...
# 961  발생 배경: 타설작업 중, 사고 종류: 콘크리트 믹서트럭 관련 끼임 사고, 사고 원...
# 962  발생 배경: 청소 작업 중, 사고 종류: 자재 관련 사고 (깨진 타일 처리 중), ...
# 963  발생 배경: 절단 작업 중 각도 절단기 이용, 사고 종류: 각도 절단기 관련 베임 ...
#
#                                                 reason  \
# 0    지반 침하 (아웃트리거 우측 상부 1개소), 아웃트리거 펼친 길이 상이, 타설 위치...
# 1                    작업자의 불안전한 행동(숫돌 측면 사용) 및 보안면 미 착용
# 2                  작업자가 전방을 주시하지 않아 발을 헛디뎌 계단에서 굴러 넘어짐
# 3                                작업 발판 위 벽돌 잔재를 밟고 넘어짐
# 4                                              작업자 부주의
# ..                                                 ...
# 959                                       약한 석재의 자연 파단
# 960                          근로자가 작업 중 이동 가능한 통로 확보 미흡
# 961     작업자가 믹서트럭 슈트 아래로 불안전하게 이동하면서 콘크리트 통사이에 손가락이 끼임
# 962                  깨진 타일을 손으로 모아 마대자루에 담으려다 파편이 박혔다.
# 963                             방호덮개 하락 지연으로 인한 재해자 손상
#
#                                     rag_summary_prompt  \
# 0    아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 1    아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 2    아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 3    아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 4    아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# ..                                                 ...
# 959  아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 960  아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 961  아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 962  아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
# 963  아래의 5개의 모범 답안 예시를 참고해 answer을 작성해주세요. 각각의 answ...
#
#                                           llm_answer_1  \
# 0    재발 방지 대책으로 작업 전 TBM 시 유사 및 동일 공종 작업자 안전교육을 실시하...
# 1    작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 ...
# 2    이동 중 작업 시 전방 주시 습관 지도 및 계단 안전 수칙 교육 강화와 함께 해당 ...
# 3            작업장 주변 정리정돈과 근로자 특별 안전교육 실시를 통한 향후 조치 계획.
# 4    점심 식사 시간 이동 시 안전 수칙 준수 교육 실시 및 안전모 착용 의무화, 작업 ...
# ..                                                 ...
# 959                            재해 예방 안전교육 실시와 특이사항 없음.
# 960  이동 통로 확보를 위한 작업 공간 정리 및 안전 표시판 설치를 통한 재발 방지 대책...
# 961  작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 ...
# 962  깨진 타일 처리 시 안전모, 보안경 등 개인 보호 장비 착용 철저, 작업 전 안전 ...
# 963  각도절단기 안전 점검 강화 및 작업자 교육 실시, 방호덮개 작동 상태 확인 철저, ...
#
#                                           llm_answer_2  \
# 0    재발 방지 대책으로 작업 전 TBM 시 유사 및 동일 공종 작업자 안전교육을 실시하...
# 1    작업자 안전 교육 강화 및 보안면 착용 철저를 통한 재발 방지, 작업 전 안전 점검...
# 2    이동 중 작업 시 전방 주시 및 안전 수칙 교육 강화와 계단 주변 안전 확보를 위한...
# 3           작업장 주변 정리정돈 및 근로자 특별 안전교육 실시를 통한 향후 조치 계획.
# 4    점심 식사 시간 등 휴식 시간 중 작업 시 안전 수칙 준수 교육 실시, 작업 구역 ...
# ..                                                 ...
# 959                            재해 예방 안전교육 실시와 특이사항 없음.
# 960  이동 통로 확보를 위한 작업 공간 정리 및 안전표지판 설치를 통한 재발 방지 대책 ...
# 961  작업 전 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지 대책 수립, 안...
# 962  사고 원인 분석 및 재발 방지 대책 수립, 안전 교육 강화 및 작업 전 안전 점검 ...
# 963  각도 절단기 사용 시 방호덮개 점검 및 유지보수 강화, 작업 전 안전 교육 철저를 ...
#
#                                           llm_answer_3  best_index
# 0    재발 방지 대책으로 작업 전 TBM 시 유사 및 동일 공종 작업자 안전교육 강화 및...           0
# 1    작업자 안전교육 강화 및 보안면 착용 의무 준수 철저요구, 작업 전 안전 점검 강화...           0
# 2    이동 중 작업 시 전방 주시 및 안전 수칙 교육 강화, 계단 안전 점검 및 개선, ...           2
# 3           작업장 주변 정리정돈 및 근로자 특별 안전교육 실시를 통한 향후 조치 계획.           0
# 4    점심 식사 시간 등 휴식 시간 동안에는 작업 중단 및 안전 교육 실시, 작업복 착용...           0
# ..                                                 ...         ...
# 959                            재해 예방 안전교육 실시와 특이사항 없음.           0
# 960  작업 중 이동 가능한 통로 확보를 위한 안전표지판 설치 및 작업 전 안전 점검을 통...           1
# 961  작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교...           0
# 962  깨진 타일 처리 시 안전수칙 준수 교육 실시, 개인 보호 장비 착용 철저, 작업 전...           1
# 963  각도 절단기 사용 시 방호덮개 설치 및 점검 철저, 작업자 안전 교육 강화, 베임 ...           0
#
# [964 rows x 14 columns]

# %% [markdown]
# ### 결과 저장

# %%
test_df['answers'] = answers

# %%
test_df.to_csv('../data/test_08.csv', index=False)

# %% [markdown]
# ### submit csv 생성

# %%
from sentence_transformers import SentenceTransformer

embedding_model_name = "jhgan/ko-sbert-sts"
embedding = SentenceTransformer(embedding_model_name)

# 문장 리스트를 입력하여 임베딩 생성
pred_embeddings = embedding.encode(answers)
print(pred_embeddings.shape)  # (샘플 개수, 768)
# Out:
# (964, 768)

# %%
submission = pd.read_csv('../output/sample_submission.csv', encoding = 'utf-8-sig')

# 최종 결과 저장
submission.iloc[:,1] = answers
submission.iloc[:,2:] = pred_embeddings
submission.head()

# 최종 결과를 CSV로 저장
submission.to_csv('../output/baseline_submission.csv', index=False, encoding='utf-8-sig')

# %%
answers
# Out:
# ['재발 방지 대책으로 작업 전 TBM 시 유사 및 동일 공종 작업자 안전교육을 실시하고, 콘크리트 펌프카 점검 항목의 필수 점검을 포함한 수시 위험성 평가를 실시하며, 지반 상태 및 아웃트리거 펼침 길이 제한을 위한 사전 안전 교육을 철저히 시행하며, 한국전력공사 내 사고 사례 전파와 안전보건협의체, 안전시공보고회의, 합동안전점검 등을 통한 관리감독자 교육을 진행하는 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '이동 중 작업 시 전방 주시 및 안전 수칙 교육 강화, 계단 안전 점검 및 개선, 작업자별 안전 수칙 준수 및 사고 발생 시 대처 요령 교육 실시 등 재발 방지 대책 마련.',
#  '작업장 주변 정리정돈과 근로자 특별 안전교육 실시를 통한 향후 조치 계획.',
#  '점심 식사 시간 이동 시 안전 수칙 준수 교육 실시 및 안전모 착용 의무화, 작업 구역 내 미끄럼 방지 조치 강화, 작업자 부주의 방지를 위한 주의 교육 실시 및 안전관리 책임자의 현장 감독 강화.',
#  '작업 전 안전발판 설치 점검 및 작업절차 준수 교육 실시, 작업 구간 위험 요소 사전 파악 및 제거, 지속적인 안전점검 및 안전교육을 통한 동종 및 유사재해 방지.',
#  '안전교육 강화 및 작업자 안전 수칙 준수 철저, 작업 전 주변 환경 점검 및 위험 요소 제거, 불안전한 행동 교정 및 작업 전 점검 철저, 수시 위험성 평가 실시 및 근로자 주지 및 확인.',
#  'SPLICE PLATE 설치 시 안전거리 확보 및 작업 시 안전 교육 철저를 통한 재발 방지 대책 마련과 추가적으로 작업 환경 개선 및 안전모 착용 철저를 포함한 향후 조치 계획.',
#  '작업발판 하단을 명확히 인지하도록 교육 실시 및 안전모 착용 점검 강화, 작업 시 집중력 향상을 위한 안전 수칙 준수 교육, 작업 전 위험 요소 사전 점검 및 미비 사항 시정 철저.',
#  '향후 작업 시 주변 안전 위험 요소 제거와 안전 교육 철저.',
#  '고령 작업자의 경우, 작업 전 건강 상태 및 기능 점검을 강화하고, 작업 환경의 미끄러운 부분에 대한 개선 및 작업 전 안전교육 철저를 통해 재발 방지 조치 및 향후 조치 계획 수립.',
#  '작업 전후 작업장 주변 정리 및 작업자 이동 경로 확보 등 현장 점검 강화, 감리자 의견에 따른 철판 궤도 설치 기준 준수 교육 실시, 유사사례 전파 및 관련 작업자 특별 교육을 통해 재발 방지 대책 마련.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '동종 및 유사재해 방지를 위한 근로자 특별안전교육 및 안전보건교육 강화, 관리 감독자의 불안전행동 예방을 위한 교육 실시, 작업 전 위험성 평가 및 안전 점검 강화, 작업 방법 교육 실시, 관리 감독 활동 강화, 작업 전 TBM 실시, 일일 TBM 시간을 활용한 위험사항 수시전파, 현장 안전점검활동 강화 등을 포함한 조치 계획.',
#  '작업자 안전교육 강화 및 작업 공간 확보, 작업 시 안전 수칙 준수 철저.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '거푸집 해체 작업 전 안전교육 강화 및 작업 순서 준수를 통한 재발 방지, 작업장 위험요소 점검을 통한 안전 교육 철저 및 향후 조치 계획.',
#  '신호수 교대 시 신호 공백 발생 방지 및 TBM 신호 확인 철저, 작업 전 위험성 평가 실시 및 근로자 주지, 작업 중 신호 재정립 및 확인.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '상호 신호 방법 재교육 실시 및 작업 전 상호 신호 체계 공유, 작업 지휘자 지정 및 감독 강화, 작업 전 위험성 평가 재 실시 및 안전 교육 철저, 동일 작업 시 작업 지휘자 배치, 작업 전 안전 점검 강화, 유사 사고 발생 시 작업 중단 및 재평가 실시.',
#  '안전 교육을 통한 불안정한 행동 방지 및 작업 전 안전 점검을 통해 작업 환경의 안전 확보를 위한 조치.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '고온 환경에서의 작업 시, 작업자 건강 관리 및 안전 교육을 강화하고, 작업 전 충분한 휴식을 취하며 집중력을 유지하도록 지도해야 합니다. 또한, 작업 표면의 미끄러운 상태를 방지하기 위한 조치를 마련하고, 작업 중 추가적인 안전 점검을 실시하여 재발 방지에 만전을 기해야 합니다.',
#  '고소작업대 작동 전 주변 환경 점검 및 작업 공간 확보, 잭 서포트 주변 정리정돈, 작업 전 작업 방법 교육 실시, 관리감독자 관리 철저, 작업자 안전모 착용 의무화 및 안전 교육 철저 시행, 작업 전 잭 서포트 위치 확인 및 안전 점검, 고소작업대 차대 이동 시 주의사항 교육 실시, 사고 발생 시 신속한 구조 및 응급처치 교육, 재발 방지를 위한 작업 환경 개선 및 안전 관리 시스템 강화.',
#  '현장 사전조사 강화 및 위험 요약서 작성, 작업 전 안전 점검 철저, 작업자 안전 교육 강화 및 작업 환경 개선을 통한 재발 방지 대책 마련.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 점검 강화 및 작업자 안전 교육 재강화, 작업 발판의 적정 높이 유지 및 안전 매트 설치를 통한 재발 방지 대책 수립.',
#  '작업자 안전교육 강화 및 작업 전 위험 요소 점검을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 임시 계단식 통로 미비 지역 접근 금지 교육 실시, 작업장 위험 요소 점검을 통한 안전 시설물 보강 및 위험성평가 재 실시, 유사 사고 재발 방지 대책 제출 통보가 포함됨.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책으로 E/V홀 내 작업 전 자재 정리 및 주변 방호 조치 지시, 작업 전 안전 점검 강화 및 2인 1조 이상 작업 진행을 통한 안전사고 예방을 위한 안전교육 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 특히 강관 동바리 설치 시 서포터의 안정적인 고정 및 작업자의 안전거리 확보에 대한 교육을 실시하고, 작업 전 위험 요소를 점검하여 유사 사고 재발을 방지해야 합니다. 또한, 안전관리 교육을 철저히 실시하여 향후 조치 계획을 수립하고 실행해야 합니다.',
#  '작업 중 이동 시 근력 유지 및 균형 감각 향상을 위한 교육 실시, 비상 상황 발생 시 신속한 대처 방법 숙지 및 관련 업체 협업을 통한 안전 점검 강화.',
#  '사고 발생 시 즉시 응급처치 및 의료 지원, 관련자 안전교육 강화, 작업 전 TBM 실시 및 안전 수칙 준수 교육, 작업 중 불안전한 자세 방지 교육, 작업 환경 안전 점검 강화 등 재발 방지 대책 수립 및 향후 조치 계획 마련.',
#  '안전 점검 강화 및 작업 통로 확보, 작업 전 안전 교육 실시, 관련 법규 준수 및 안전 관리 철저.',
#  '작업자 간 신호체계 확립, 안전한 작업절차 진행, 근로자 안전교육 실시를 통한 안전의식 고취 및 재발 방지 대책 마련.',
#  '안전보호구 착용 의무화 및 안전모 착용 철저와 작업 전 안전교육 실시, 넘어짐 사고 예방을 위한 작업 환경 점검 및 개선, 작업 시 주의사항 재교육 실시.',
#  '현장 책임자에 의한 관리 감독 철저와 TBM시간 활용을 통한 안전교육 실시로 유사사고 재발 방지.',
#  '작업자 간 의사소통 강화 및 지시사항 명확히 전달, 작업 중인 구조물 안정성 점검 및 수시 확인, 작업 전 안전 교육 철저, 안전 관리 책임자의 감독 강화 및 안전 점검 실시 등의 조치.',
#  '재발 방지 대책 및 향후 조치 계획으로 작업 신호 체계 강화 및 명확한 신호 전달 체계 구축, 작업자 간 의사소통 활성화, 작업 전 안전 점검 및 위험 요소를 사전에 제거하고, 안전 교육 강화 및 작업장 위험요소 점검을 통해 재발 방지하고 안전관리 교육 철저를 통해 향후 조치를 취해야 한다.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '해당 구간의 지반 상태에 대한 정밀 점검을 실시하고, 굴곡진 구간에 대한 사전 경고 시스템을 구축하여 추가적인 지반 관련 사고 발생을 예방하며, 작업 전 안전 교육을 통해 근로자 안전 의식을 고취하는 재발 방지 대책과 향후 조치 계획.',
#  '작업 전 미끄러짐 방지 교육 강화 및 작업장 환경 점검을 통한 개선, 작업 중 와이어 사용 자제 및 안전띠 착용 의무화, 작업 지휘자 상주 및 작업 감독 강화, 유사 재해 발생을 예방하기 위한 작업 방법 개선 및 교육 실시.',
#  '베임 방지 장갑 착용 의무화 및 커터칼 등 날카로운 도구 사용 시 주의사항 교육 강화, 작업 전 안전 점검 철저를 통한 재발 방지 및 향후 조치 계획 수립.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 신호 체계 및 통신 방법 교육을 강화하고, 작업자 간 협업을 위한 정기적인 훈련을 실시해야 합니다. 또한, 작업 전 신호 체계 및 통신 방법 교육을 강화하고, 작업자 간 협업을 위한 정기적인 훈련을 실시해야 합니다. 작업 중에는 신호 불일치 발생 가능성을 최소화하기 위해 작업자 간 지속적인 소통과 확인을 통해 안전하게 작업을 진행해야 합니다.',
#  '안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '즉시 안전 점검 강화 및 작업 전 균형 감각 훈련 실시, 작업 환경 위험 요소 제거, 안전모 및 안전화 착용 의무화 철저히 준수.',
#  '정비 후 작업 전 안전 점검을 강화하고, 정비 일정 준수 및 정비 기록 관리 철저를 통해 덤프트럭 브레이크 파열 사고를 예방하며, 작업자 안전교육을 실시하고 현장감독을 철저히 하는 조치 계획.',
#  '개인 보호구(안전화) 착용 의무 준수 및 정기적인 안전 점검 실시, 안전화 착용 상태 및 손상 여부 확인을 위한 근로자 교육 강화, 유사 사고 발생 시 즉시 보고 및 조치 절차 숙지.',
#  '트렌치 작업 시 빙판 제거 및 안전 표지판 설치, 작업 전 충분한 이물질 제거 및 안전 교육 실시, 작업자들의 안전 의식 고취를 위한 자체 교육 및 훈련 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '주출입구 및 빙판이 발생 가능한 지역에 대한 TBM(Toolbox Meeting)을 통해 경고를 강화하고, 작업자들에게 바닥 상태에 대한 지속적인 주의를 당부하며, 미끄럼 방지 신호판 설치 및 보행 속도 제한 등의 조치를 취할 것임.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 개인보호구 착용 및 관리상태 점검, 관리감독자의 현장 상주를 통한 주요 위험요인 점검 및 제거, 향후 조치 계획 수립.',
#  '안전관리 강화 방안으로 굴착 전 토질 분석 및 흙막이 설치, 작업 전 굴착사면 상태 확인 철저, 안전감시자 현장 감독 강화, 작업자 안전 의식 고취를 위한 특별 안전 교육 실시, 계약상대자 관리자 책임 강화 및 안전관리 시스템 준수 여부 점검, 향후 재발 방지 대책 수립 및 시행.',
#  '이동 통로 확보 및 실족 방지망 설치, 2인 1조 작업 실시, 용접기 및 용접선 이동 시 안전벨트 착용 철저, 작업 반경 내 보행자 통행 금지 등 재발 방지 대책 수립 및 안전관리 교육 강화.',
#  '유로폼 운반 시 안전벨트 착용 및 견고한 방법으로 운반하고, 작업장 주변 자재 정리 및 작업자 교육을 통해 안전사고 예방을 위한 조치 계획 수립.',
#  '안건거리 확보 기준 명확화 및 점검 강화, 작업 전 안건거리 확보 지시 철저, 작업자 안전 교육을 통한 위험성 인식 개선.',
#  '고소작업대 사용 시 안전 점검 강화 및 고정 장비 점검 철저, 작업 전 안전 교육 및 2인 1조 작업 실시, 작업 환경 주변 정리정돈을 통한 안전 확보, 유사 사고 재발 방지를 위한 작업 매뉴얼 제작 및 교육 실시 예정.',
#  '작업 전 안전교육 강화 및 작업구간별 사전 위험성 평가 실시, 작업 전 안전 점검을 통한 위험 요소 제거 및 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 개인 보호구 착용 의무화 및 작업 시 주의사항 숙지, 작업 계획서 작성 및 안전교육 실시를 통한 안전 관리 방안.',
#  '작업 전 안전 점검 강화 및 작업 중 안전 수칙 준수를 위한 교육 실시와 향후 유사 사고 재발 방지를 위한 대책 마련.',
#  '근로자 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전 교육 강화 및 작업장 내 위험 요소 점검을 통한 재발 방지, 안전 관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 통로 이용을 위한 안전 교육 실시 및 작업장 통로 확보를 통한 재발 방지 대책, 현장 관리감독 철저.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 위험 요소 제거, 작업 중 주위 확인 철저, 계단식 무대 주변 통로 확보 및 관리 감독 강화, 안전 점검을 통한 위험 요소 즉시 제거 및 조치.',
#  '안전덮개 설치 및 작동 확인 절차 준수 교육 강화, 작업 전 톱류기 작동 중지 절차 숙지, 톱류기 작업 시 안전거리 확보, 작업자 안전 교육 철저.',
#  '체인블록 설치 의무화 및 작업 전 안전 점검 강화, 그리고 작업자에게 체인블록 사용법에 대한 재교육 실시를 통한 향후 조치 계획.',
#  '현장 작업구간 구획표시 강화 및 정리정돈 상태 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '틀비계 작업 시 안전모 및 안전화 착용 의무화 교육 실시, 추락 방지를 위한 안전대 착용 교육 및 작업 순서 숙지, 망지 등 보호 장비 착용 시 안전 점검 실시, 작업자 안전 특별 교육 및 추락 방지 장비 점검 수시 확인.',
#  '작업자에게 사전 작업 계획의 중요성 및 안전 수칙에 대한 교육 실시, 작업 전 작업자 안전 점검 강화, 작업자에게 불안전한 자세로 작업하는 행위 지양 및 안전 수칙 준수요청, 관리감독자 배치 철저.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 작업 전 체력 관리에 대한 교육 실시, 작업장 정리 정돈 철저, 작업 중 휴식 시간 보장, 무거운 물품 운반 시 추가 인력 투입 검토, 작업자 체력 관리 교육 실시 및 작업 중 휴식 시간 보장, 작업 중 체력 불만족 시 즉시 작업 중단 및 보고.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전 교육 내용 보강 및 작업 전 안전 점검 강화, 작업자별 안전 수칙 준수 교육 실시, 위험물 관리 및 비상 대응 훈련 실시.',
#  '2인 1조 작업 실시 및 안전대 착용 의무화, 사다리 작업 전 안전 점검 강화, 안전 교육 재시 실시를 통한 향후 조치 계획.',
#  '콘판넬 사용 시 안전 교육 강화 및 안전 수칙 준수, 작업 전 주변 정리정돈 철저, 낙하물 방지 시설 설치 및 점검, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전 교육 강화 및 작업 중 불안전한 행동에 대한 주의 교육 실시. 비계 작업 시 작업 계획 승인 및 지속적인 안전 교육을 통해 유사 사고 재발 방지.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '인발 작업 시 슬링바 체결 상태를 2차 확인하고, 작업 전 안전교육 및 작업 전 위험 요소 점검을 실시하여 재발 방지. 또한, 현장대리인 및 공사감독의 상주와 안전관리 철저, 개인보호구 착용, 작업 전 안전조치 및 안전교육, 공동작업 실시 등의 조치 계획을 통한 재발 방지.',
#  '작업자 안전 교육 강화, 통로 확보 점검 실시, 작업 전 사전 안전 점검 철저, 작업 환경 개선 조치 시행.',
#  '미끄럼 방지 시설 설치 및 점검 강화, 작업 전 안전 교육 실시, 작업자 주의 분산, 계단 관리 감독 강화, 향후 유사 사고 예방을 위한 작업 절차 재정비 및 교육 실시.',
#  '자재 정리 시 작업 전 안전 점검 및 위험 요소를 확인하고, 작업 중 자재 주변에 사람이 접근하지 않도록 주의를 기울여야 합니다. 또한, 작업 전 안전 교육을 강화하고, 작업장 내 안전 수칙 준수를 통해 재발을 방지해야 합니다.',
#  '안전대 착용 및 작업 환경 점검의 철저함, 작업 전 위험 요소 평가 및 통제, 안전관리 교육 강화, 작업 후 안전 점검 실시.',
#  '상하 작업 전 안전교육 강화 및 위험물질 관리감독 철저를 통한 재발 방지 대책 이행 여부 확인 및 작업 전 안전 점검을 통한 추가적인 위험 요소 제거.',
#  '하카 사용 시 반발력에 대한 작업자 안전 교육 강화, 하카 사용 전 주변 정리 및 위험물 투입 시 보호구 지급, 작업 전후 안전 점검 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '잭서포트 고정 상태 점검 강화 및 타설 시 진동 최소화 대책 마련, 작업전 안전교육 철저 및 작업장 위험 요소 점검 실시.',
#  '재발 방지 대책으로 작업 전 위험반경 내 인접 노무자 이동 통제 강화, 고압 산소가스 주입 시 작업 전 점검 및 안전 교육 실시, 고무주름관 고정 장비 점검 강화, 작업 전후 위험 반경 내 안전 점검 실시, 유사 사고 발생 시 즉시 작업 중단 및 안전 점검 실시, 향후 근로자의 안전 교육과 안전 점검 강화 및 작업 지휘자 배치 확대 등을 통해 재발 방지 대책을 추진.',
#  '작업 전 공구 점검 및 사용법 숙지 교육 강화, 작업 중 공구 사용 상태 지속적인 확인, 작업자 공구 사용 습관 개선을 위한 교육 실시 및 작업장 내 안전수칙 준수 철저 지시.',
#  '작업 전 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '현장 안전 관리 시스템 강화 및 작업 전 안전교육 내용 보강, 작업자 안전보호구 착용 의무화 및 정기 점검, 사고 현장 보존 및 재발 방지 대책 마련.',
#  '근골격계 질환 예방을 위한 수시 스트레칭 및 올바른 중량물 취급방법 교육 실시와 작업 전 자체 시스템을 통한 근로자 건강상태 파악을 포함한 향후 조치 계획.',
#  '작업자 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전 점검 강화 및 비상 연락 체계 점검, 붕괴 위험 지역 접근 금지, 붕괴 발생 시 대응 매뉴얼 숙지 및 훈련 실시, 사고 현장 보존 및 정확한 원인 분석, 향후 유사 사고 예방을 위한 붕괴 방지 대책 수립 및 적용.',
#  '전동톱 사용 전 자재 상태 점검 및 박힌 못 위치 확인 철저, 작업 전 안전교육 실시, 작업장 정리정돈 철저, 근로자의 안전 의식 고취 및 주의사항 재강조.',
#  '작업자 안전교육 강화 및 작업장 바닥 정리를 통한 재발 방지, 안전모 및 안전화 착용 철저.',
#  '재발 방지 대책 및 향후 조치 계획 수립: 작업 전 톱날 및 공구 상태 점검 강화, 방호 장비 착용 의무화, 작업자 교육 시 위험 요소 및 안전 수칙 집중 교육 실시, 사고 발생 시 즉각적인 응급처치 및 의료 지원 제공, 향후 유사 사고 방지를 위한 안전 관리 시스템 개선 및 정기적인 안전 점검 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '근로자 안전관리 교육 강화 및 작업 전 위험 요소 점검을 통한 재발 방지, 작업 순서 및 2단 거푸집 작업 시 주의사항 교육 철저를 통한 향후 조치 계획 수립.',
#  '작업자 간 수신호 체계 교육 실시 및 수신호 전달 정확성 평가를 통한 개선 방안 마련.',
#  '개인적인 부주의로 인한 사고 발생에 대한 안전 교육 강화, 작업 전 안전 점검 철저, 작업 중 집중력 향상 훈련 실시, 작업 절차 준수 및 위험물 취급 교육 재강화.',
#  'TBM 작업 시 안전화 점검 의무 준수 및 작업 현장 안전 교육 강화, 특히 TBM 작업 중 발생 가능한 위험 요소를 인지하고 안전 수칙을 철저히 준수하도록 교육 실시.  작업 전 정비 후 안전 점검을 통해 위험 요소를 사전에 제거하고, 작업 중에는 항상 안전을 최우선으로 하는 자세를 유지하도록 지시한다.',
#  '작업간 안전교육 실시 및 안전 강조, 작업 반경 내 접근 금지 구역 설정 및 관리 강화, 유도자에게 굴착기 작동 시 안전 수칙 교육 실시, 향후 조치 계획으로 작업 반경 관리 시스템 구축 및 운영, 유사 사고 재발 방지를 위한 근로자 교육 강화.',
#  '작업 전 안전 교육 강화 및 작업장 미끄러짐 위험 요소 제거 (미끄럼 방지 매트 설치 등)를 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '쇠지렛대 사용 작업 시, 작업자 안전교육을 강화하고, 쇠지렛대 사용 전 작업 공간 정리 및 주변 안전 확인을 실시하며, 작업 시 안전모 및 보호 장비 착용을 철저히 시행하고, 작업 전후 스트레칭을 통해 근골격계 건강 관리 및 작업 집중도 향상 도모, 향후 동일한 작업 시 관리감독자 및 안전관리자를 통한 집중관리와 해당 팀원 특별안전보건교육을 통한 안전작업수칙 및 안전의식 함양.',
#  '정기적인 밧줄 점검 및 교체 주기 준수, 밧줄 안전 고리 상태 점검, 작업 전 밧줄 안전 점검 실시, 작업자 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 현장에 대한 즉각적인 안전진단 실시 및 비계 보강 조치, 전방 주시 습관 개선을 위한 안전 교육 실시, 관련 작업자 대상 특별 안전 교육 실시.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책 및 향후 조치 계획으로 작업 전 안전 교육 강화, 작업 환경 사전 숙지 및 위험 요인 점검 실시, 작업 중 비계 해체 시 2인 1조 작업 실시 및 안전 표지판 설치, 비계 해체 등 위험 작업 시 올바른 작업 방법에 대한 근로자 안전교육 실시, 작업 전후 안전 점검 실시 및 미비 사항 보완.',
#  '작업자 안전 수칙 준수 특별 교육 실시, 작업 전 철근 위치 파악 및 주의, 드릴 잡는 힘 강화 훈련, 작업 중단 시 즉시 작업 중단 절차 숙지, 작업 외 시간 작업 중단 및 임의 작업 관리 철저 요청.',
#  '안전모 일체형 보안경 착용 관리 철저, 사고사례 전파 및 안전교육 실시를 통한 근로자 안전의식 고취, 작업장 위험 요소 점검 강화.',
#  '작업 시 자세 교육 실시 및 숙련도 향상을 위한 추가 교육을 실시하고, 작업 전 안전 점검을 강화하여 재발 방지 대책을 마련하며, 향후 조치 계획 수립.',
#  '기술적 대책으로 말비계 사용 시 안전대 착용 의무화 및 정기적인 안전 점검 실시, 교육적 대책으로 동종 재해 예방 안전 교육 실시를 통한 안전 수칙 준수 및 위험물 관리 강화.',
#  '작업 전 위험 요인 평가 및 안전 교육 강화, 굴착기 운전 시 작업자 안전 확보를 위한 사전 협조 및 경계, 작업 공간 안전 확보, 굴착기 작업 시 관리감독자 현장 배치, 안전사고 재발방지 교육 실시 및 관련 지침 준수 철저.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 원인 분석을 바탕으로 갱폼 유닛의 안전한 고정 및 이탈 방지를 위한 작업 전 안전 교육 강화, 갱폼 유닛의 체결 상태 점검 및 유지, 작업자 안전 교육 철저, 현장 안전 관리자 상주 및 감시, 추락 방지 시설 설치 등 즉각적인 안전 대책을 마련하고, 향후 유사 사고 재발 방지를 위한 작업 절차 개선 및 정기적인 안전 점검을 실시할 예정이다.',
#  '작업자와 근로자에 대한 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 유로폼의 바닥 튕겨나감 방지 대책 마련, 작업 중 유로폼의 안정적인 고정 및 주변 정리정돈 철저, 낙하물 방지 경고문 부착, 작업자에게 안전 수칙 준수 교육 및 작업 중 주의 분산 방지 교육 실시, 사고 발생 시 응급 조치 및 의료 지원 체계 구축.',
#  '하부작업자 통제 강화 및 안전 점검을 통한 사고 예방, 작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 작업 지휘자 배치 및 작업 방법 지도, 2인 1조 근무 형태 확인, 안전표지판 설치 및 안전 수칙 준수 지도, 작업 전 하부작업자 안전 점검 실시.',
#  '재발 방지를 위한 안전교육 실시, 동바리 멍애의 즉시 고정조치, 작업 전 안전 점검 강화, 작업 중 안전 수칙 준수 지도, 현장대리인 및 상주감리원, 안전관리자의 수시 점검 등.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 표면 정리정돈 실시 및 작업 환경 개선, 안전교육 강화 및 작업 전 점검 철저를 통한 재발 방지, 향후 유사 사고 예방을 위한 안전 수칙 준수.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 특히, 외부 비계 작업 시 작업자들의 안전 의식 고취를 위한 교육 실시 및 작업 전 하부 통제자에게 알리고 하부 통제 교육을 실시하며, 비계 작업 전 하부 통제선을 설치하고 관리감독자를 배치하여 철저히 관리하는 것이 필요합니다.',
#  '가설계단 및 비계 안전 수칙 준수 교육 강화, 비계 주변 작업 시 안전 매트 설치 확인, 작업 전 현장 관리자 확인 및 작업 동선 재점검 실시, 안전 점검 강화 및 안전 관리 교육 철저를 통한 향후 조치 계획.',
#  '안전 교육 강화 및 작업 현장 안전 점검을 통해 위험 요소를 제거하고, 안전 작업 수칙 준수를 위한 지도를 실시하여 재발 방지할 것.',
#  '핸드 가라인더 사용 시 작업 전 덮개 확인 및 작동 상태 점검 교육 실시, 작업 시 안전모 및 보호 장비 착용 철저, 작업 시 안전거리 확보 및 주변 사람에 대한 경고 등 안전 수칙 준수 교육을 강화하고, 향후 유사 사고 재발 방지를 위한 안전 관리 감독 강화 및 작업자 안전 의식 고취가 필요합니다.',
#  '발판 결빙으로 인한 재발 방지 대책 마련 및 작업 전 발판 상태 점검 강화, 미끄럼 방지 안전 매트 설치, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '스트러트 설치 작업 시 안전고리 체결 상태 점검 강화 및 안전화 착용 시 미끄럼 방지를 위한 작업 환경 개선, 작업자 안전교육 철저를 통한 재발 방지 대책 마련.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '시스템 비계에서 목재가 떨어지는 상황 발생에 대한 안전 교육 강화 및 작업 환경 점검을 통해 유사 사고 재발 방지, 작업 중 안전보호구 착용 의무화 및 작업 전 주변 정리 정돈 철저, 작업자 안전의식 고취를 위한 정기적인 안전 교육 실시.',
#  '회전기기 작업 시 작업 전 안전 점검을 철저히 실시하고, 작업 중에는 항상 안전 거리를 확보하도록 교육하며, 작업자 부주의로 인한 유사사고 발생을 방지하기 위해 안전 교육 및 작업 시 안전관리 철저를 통해 향후 조치 계획을 수립한다.',
#  '작업자 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지를 위한 작업 전 정리정돈 철저, 작업 공간 분리 및 통로 확보, 안전모 및 안전화 착용 의무화, 작업 중에는 주변 상황 주시 및 안전수칙 준수, 작업 전 안전교육 철저 및 특수안전보건교육 실시.',
#  '안전교육 실시와 현장정리정돈 관리와 당사 본사 보고에 따른 일반재해 처리 매뉴얼 준수.',
#  '작업자 안전교육 강화, 작업발판 고정 철저 및 미끄럼방지테이프 추가 설치와 현장 지도감독 강화로 인한 재발 방지 대책.',
#  '안전시설물 관련 작업 시 장비운전원 및 신호인 체계 일치 교육 실시, 작업 전 안전 점검 강화, 작업 구간별 안전 수칙 준수 교육 실시, 작업자 간 의사소통 강화 및 비상 연락 체계 구축, 안전사고 재발 방지 대책으로 작업 환경 개선 및 안전 점검 시스템 구축 예정.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '근골격계 질환 예방을 위한 수시 스트레칭 및 올바른 중량물 취급방법 교육 실시와 작업 전 자체 시스템을 통한 근로자 건강상태 파악을 포함한 향후 조치 계획.',
#  '손낌 방지 장치 설치 및 미비한 작업 환경 점검을 통한 재발 방지 교육 실시, 작업자 안전 교육 강화, 작업 전 안전 점검 실시, 작업 중 안전 수칙 준수 교육 실시.',
#  '작업 전 지반 상태 점검 및 보강 작업 실시, 미끄러운 지면에는 작업 표지판을 설치하여 위험 요소를 알리고, 작업자 안전 교육을 강화하여 동일 사고의 재발을 방지하는 조치 계획 수립 및 작업 전후 안전 점검 실시 후 개선 사항 반영.',
#  '이동식 사다리 안전 점검 강화 및 안정화 작업 시 2인 1조 작업 시행, 작업 전 작업 공간 정리 정돈을 통한 안전 통로 확보, 작업 지휘자 배치 및 안전 교육 철저를 통해 재발 방지 조치.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전매트 설치 및 개인 보호구 착용 철저를 위한 작업 전 교육 실시, 작업 시 안전 수칙 준수 여부 지속적인 감독 및 점검.',
#  '자재 정리 정돈 강화 및 작업 전 안전교육 철저, 작업 시 주의 의무 준수 강조, 향후 현장 점검 시 작업 구역 정리 상태 및 근로자의 안전 수칙 준수 여부 확인.',
#  '작업 전 안전 교육 강화 및 위험요소 점검을 통한 재발 방지 대책 마련, 2인 1조 작업 원칙 준수 교육 실시, 중량물 운반 시 안전 속도 관리 및 보호구 착용 철저, 사고 현장 보존 및 관련자 전원 교육 실시.',
#  '장기간 형틀 공사로 인한 근로자 건강 상태 검진 강화, 직업 환경 측정 및 환기 시설 점검, 장시간 작업 시 휴식 시간 보장, 작업 환경 개선을 위한 환기 시설 점검 및 보강, 직업 환경 관련 법규 준수 및 근로자 건강 관리 교육 실시, 작업 관련 질병 예방을 위한 정기적인 건강 상담 및 교육 실시.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '해치발판 관련 안전시설 설치를 포함한 작업 전 위험 요소 검토 및 안전 점검 강화, 작업자 안전 교육 철저를 통한 재발 방지 대책 마련.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전교육 추가 실시와 강화에 따른 재발 방지 대책. 작업 시 상부 추락 방지 교육 철저 및 안전모, 안전벨트 등 개인보호구 착용 의무화. 사고 발생 지점 안전 점검 및 위험 요소 제거, 작업 절차 준수 및 작업자 주의 집중.',
#  '작업 전후 스트레칭 실시 및 적절한 휴식시간 준수를 위한 관리감독 강화, 근로자 교육을 통한 안전 의식 고취를 통한 재발 방지 대책 마련.',
#  '작업 전 위험 요인 평가를 통해 미끄럼 방지 시설 설치 및 작업 공간 확보, 안전 교육 강화 및 작업자 보호 장비 착용 철저 지시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '응급 상황 발생 시 신속한 대처를 위한 비상 연락망 구축 및 교육 실시, 근로자 정신 건강 관리 프로그램 도입 검토, 작업 전 건강 상태 확인 및 정신 건강 상태 상담 지원, 작업 환경 위험 요인 점검 강화 및 안전 교육 철저, 관련 법규 및 안전 수칙 준수 강조, 사고 발생 시 신속한 응급 처치 및 이송 시스템 구축, 원인 규명을 위한 철저한 조사 실시.',
#  '1톤 로라 다짐 작업 시 후방 감시자 배치 및 작업자들의 철저한 안전 교육 실시, 작업 전 스트레칭 실시, 안전모 및 안전화 착용 의무화.',
#  '지정된 이동 동선 준수 및 작업 구역 내 위험물 관리 강화와 작업에 대한 안전교육 실시.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 작업 시 안전 장비 착용 확인, 작업 반장 및 안전관리자 배치 확인, 관련 작업 재교육 실시 및 현장 안전 확보 방안 수립 등.',
#  '용접 품질 관리 강화 및 작업 전 철저한 검토, 작업자 안전 교육 집중 실시, 재발 방지 대책 마련.',
#  '거푸집 설치 시 인원 간 의사소통 강화 및 협업 교육 실시, 작업 전 안전 점검 및 위험 요소를 명확히 인지하도록 하고, 유사 사고 재발 방지를 위한 교육 실시 및 현장 관리 감독 강화.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '장기간 소음 노출 관련 근로자 건강 상태 정기적인 건강검진 실시 및 소음 노출 위험 감소를 위한 작업 환경 개선 및 개인 보호구 착용 철저, 작업 환경 측정 및 관리 강화, 소음 노출 관련 근로자 건강 교육 실시.',
#  '바닥 단차 확인 및 보수 작업 전 정밀 점검 강화, 작업 전 안전교육 철저 및 작업자 안전 의식 고취를 통한 재발 방지 대책과 현장 안전관리 감독 강화 및 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '자재 운반 시 정리정돈 철저와 안전 수칙 준수를 통한 재발 방지 대책 및 향후 조치 계획 수립.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전 교육 강화 및 작업 전 위험요소 점검을 통한 재발 방지 대책, 작업 지휘자 지정 및 감독 강화, 작업자 안전 수칙 준수 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 정기적인 위험요소 점검 실시 및 작업장 정리정돈 철저를 통해 작업 환경의 안전성을 확보하고, 작업자에게 안전수칙 교육을 강화하여 사고 발생 시 즉각적인 대처 능력을 향상시키는 방안.',
#  '인상작업 중 안전 관리 강화 및 작업 중단 시 즉시 안전 점검 실시, 비계 및 작업 환경 재평가, 작업자 안전 교육 철저 및 안전 관리자 현장 지시.',
#  '근로자 안전교육 강화 및 보행부 미확보 점검 실시, 미끄러운 지형 및 날씨 등 작업 환경에 대한 안전 교육 철저, 작업 전 안전 점검 실시 후 작업 시작, 작업 중 보행부 미확보 점검 및 안전 확보 후 작업 진행.',
#  '작업 전 강풍 상황을 고려한 안전 교육을 실시하고, 바람이 심한 날씨에는 양생 작업 중단 등의 사전 예방 조치를 취해야 함. 또한, 천막 고정 장비의 안전 점검을 강화하고, 작업자 안전 수칙 준수를 철저히 관리 감독하여 유사 사고 재발을 방지해야 함.',
#  '작업 공간 확보 및 작업 공간 내 위험 요소 제거, 작업자 안전 교육 강화 및 작업 방법 개선, 유사사고 예방을 위한 교육 전파 및 안전 점검 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '동절기 저하로 인한 작업자의 신체활동 저하 및 말비계 접근 시 미끄럼 방지 대책 마련, 작업 전 안전 점검 강화, 작업자에게 안전 교육 실시 및 말비계 안전 점검을 통해 사고 발생 가능성을 최소화하는 조치 계획 수립.',
#  '철근 식별 표시(위험 정보)의 적정성 및 시인성을 확보하기 위한 교육 실시, 인근 공정 작업자와의 협업을 통한 위험 정보 공유 시스템 구축, 작업 반경 내 위험 요소 관리 강화 및 작업 전 안전 점검 철저.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 실시 및 자재 정리정돈 습관화, 작업 구역별 위험물 관리 강화, 작업발판 설치 시 안정성 점검 실시, 작업 시 주의사항 교육 및 안전 수칙 준수 철저를 통한 재발 방지 대책과 향후 조치 계획 수립.',
#  '작업 전 안전 점검 강화 및 작업장 내 단차 제거를 통한 재발 방지 대책 수립 및 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '지반 상태 점검 및 보수, 작업 전 안전 교육 강화, 작업 지휘자의 지시사항 준수, 건설기계 운전자의 안전 수칙 숙지 및 준수, 경사지면 작업 시 추가 안전 조치 시행.',
#  '레미콘 운전원 대상 특별안전교육 실시와 작업 시 방심 방지를 위한 주의 교육 강화, 작업 환경 점검을 통한 위험 요소 제거 철저를 포함한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 위험요소 확인 및 전달 시스템 강화, 작업 전 안전 점검 실시, 안전 교육의 철저한 이행을 통해 재발 방지 및 향후 조치 계획 수립.',
#  'PT 아시바 작업 시 어지러움 증상 발생 시 작업 중단 및 안전교육 강화, 안전모 및 안전대 착용 철저, 작업 전 건강 상태 점검, 낙상 위험 지역별 안전시설물 설치 및 점검, 유사사고 재발 방지를 위한 교육 실시.',
#  '작업 현장의 안전통로 확보 및 유지, 자재 정리정돈을 위한 교육 강화, 작업자 안전 의식 고취를 위한 교육 실시 및 안전 점검을 통해 유사사고 재발 방지.',
#  '문틀 주변 정리 정돈 및 안전 표지판 설치, 작업 전 전기 안전 점검 실시, 작업자 안전 교육 강화 및 사고 발생 시 즉시 보고 및 작업 금지 조치로 인한 안전 확보.',
#  '201동 지하 계단실 위험 요인 개선 및 이동 중 공구통 운반 시 안전 수칙 준수 교육 실시, 작업 전 주변 환경 점검을 통한 재발 방지 대책 마련.',
#  '근로자 및 관리감독자의 안전관리 강화 교육 실시, 작업발판의 안정성 확보를 위한 정기적인 점검 실시, 작업 중 넘어짐 방지를 위한 안전모 착용 및 안전화 착용 실시, 작업 중 중심 잡기 교육 실시, 작업 중 안전 수칙 준수 교육 실시, 작업 중 관리감독자 현장 상주관리 강화, 동종 및 유사사고 재발방지를 위한 근로자 안전교육 및 작업장 정리정돈 강화.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '근로자 특별안전교육 실시, 보안경 착용 교육 강화, 작업 시 보안경 얼굴 밀착 착용 관리 감독, 작업 환경 점검을 통한 보안경 틈새 유발 요인 제거, 유해위험기계기구 안전작업 표지판 부착.',
#  '건식 PD 작업 시 돌출된 피스에 대한 위험 요인 인지 교육 강화 및 작업 전 정비구 확인 철저, 개인 보호구(장갑) 착용 관리 철저를 통한 향후 조치 계획.',
#  '외부 비계 해체 작업 시 작업자 주의를 환기시키고, 안전 교육을 통한 작업자 안전 의식 향상을 요청한다. 또한, 비계 해체 작업 전 안전 점검을 통해 작업 환경을 점검하고, 작업 중 안전사고 예방을 위한 조치를 취한다.',
#  '작업구간 안전난간대 설치 및 안전장비 착용 철저, 발판 설치 상태 점검 강화 및 작업자 안전교육 실시, 작업 전 위험 요소 확인 및 통로 확보를 위한 관리 감독 강화.',
#  '지정된 이동통로 사용 의무화 및 교육 실시, 작업 전 안전 점검 강화, 작업자 교육 시 이동통로 사용 요령 및 주의사항 강조를 통한 재발 방지 대책 이행 여부 확인.',
#  '작업 전 안전점검 강화 및 정해진 이동통로 준수 교육 실시, 작업 중에는 항상 주변 상황을 주시하며 통제선 위반을 방지, 작업 지휘자의 지속적인 감독 및 관리감독을 통해 작업자들의 안전 의식 제고 및 사고 예방.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '전방 주시 철저 및 작업 전 위험성 평가 실시, TBM 강화 및 정기 교육을 통한 안전 의식 고취, 작업 전 관리감독자 확인 및 작업 전후 주의사항 재확인, 작업 환경 위험 요소 제거 및 개선, 유사사고 재발 방지 대책 제출.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 발판의 안전 점검 강화 및 작업자 교육을 통해 유사 사고 재발 방지, 작업 전 안전 교육 실시 및 작업 방법 준수 철저.',
#  '작업구간 정리 및 잉여자재 즉시 처리, 운반자재의 적재량 준수 및 안전 관리 강화, 그리고 작업 환경의 안전 확보를 위한 교육 실시 및 안전보호구 착용 철저를 통해 재발 방지 대책 수립 및 안전관리 철저.',
#  '작업자 및 근로자에 대한 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전 관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전고리 착용 의무화 및 작업 전 위험 요소 확인, 작업장 정리 정돈 철저를 통한 재발 방지 대책 및 향후 안전 점검 및 작업자 안전 교육 계획.',
#  '결빙구간 즉시 제거 및 안전한 작업 환경 조성, 이동식 틀비계 안전 점검 강화, 작업 전 안전 교육 및 작업 전후 스트레칭 실시, 작업자들의 안전 의식 고취 및 위험 상황 발생 시 즉시 정지하도록 교육 실시.',
#  '사다리 작업 시 아웃트리거 설치 및 지반 상태 확인, 해당 내용 전파와 안전관리 교육 실시, 안전 관리 철저, 작업자 산재 처리 및 재발 방지 대책 조치 여부 확인과 관리 감독 철저.',
#  '이동 시 주의 교육 강화 및 작업장 내 위험 요소 점검을 통한 재발 방지 대책 수립, 안전관리 교육 철저를 통한 향후 조치 계획 실행.',
#  '작업 전 현장 안전 점검 강화 및 미끄럼 방지 시설 설치, 작업자 안전 교육 철저를 통한 재발 방지 대책 마련, 작업 구역 내 주변 물체 정리 및 확보.',
#  '근로자 건강 상태 확인 절차 강화 및 관리자 책임 강화 조치 계획 수립, 작업 전 안전 점검 철저 실시 및 작업자 안전 교육 재강화.',
#  '안전교육 강화 및 작업장 정리 정돈 철저를 통한 재발 방지 대책 수립, 안전사고 예방을 위한 작업 전 안전 점검 실시 및 현장 안전 관리 감독 강화 예정.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업자의 행동 교육을 통해 불완전한 행동 예방, 작업장 내 위험 요소 점검을 통한 재발 방지 대책 수립 및 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지를 위한 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 특히 벤딩배관 하역 시 후크 해지 상태 확인 절차 준수 및 작업 전후 확인을 포함한 안전 교육을 실시하고, 현장 점검을 강화하여 유사 사고 발생을 예방해야 한다.',
#  '작업 전 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 실시 및 작업 절차 준수 철저, 작업 현장 정리 정돈, 그리고 작업자 부주의로 인한 사고 예방을 위한 추가적인 위험 요소 점검 및 안전 수칙 교육 실시를 통한 향후 조치 계획.',
#  '작업자 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 점검 강화 및 작업 발판 설치 시 안전 기준 준수 확인, 작업자 안전 교육 실시 및 안전 수칙 준수 강조, 작업지휘자의 작업장소 순회점검 및 위험 요소 사전 제거, 발주청 및 시공자 안전관리 교육 및 재발 방지 대책 수립.',
#  '양중 작업 전 철저한 위험성 평가 및 작업 계획 수립, 작업자별 역할 분담 명확화, 작업 전 의사소통 강화 및 동료 상시 감시 체제 구축, 작업 전 충분한 준비 상태 점검, 고소작업대 사용 시 안전 수칙 준수 교육, 작업 진행 중 발생하는 이상 징후 즉시 중단 및 보고, 작업자 간 힘의 불균형 방지를 위한 작업 방법 개선, 작업 환경 정리 정돈, 안전 교육 및 훈련 강화, 유사사고 재발 방지를 위한 재발성 위험 요인 분석 및 개선, 작업 전후 안전 점검 실시, 안전 관리 책임자의 책임 강화, 작업자 안전 의식 고취 및 안전 수칙 준수 독려.',
#  '안전 교육 강화 및 작업 전 안전 점검 철저를 통한 미끄러운 상태에서의 작업 주의 안내, 작업 시 안전화 착용 의무 강조 및 작업장 주변 상태 확인을 통한 재발 방지 대책 수립.',
#  '사고 원인 분석을 바탕으로 작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획 수립.',
#  '현장 내 안전 미비요인 제거와 재발 방지 교육 실시 예정.',
#  '작업자 부주의로 인한 재발 방지 대책으로 작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 안전 관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '운전원 및 재해자 모두 주변 상황 파악의 중요성을 강조하는 교육 실시, 운반 작업 전 안전 점검 강화 및 작업 중 지속적인 위험 요소 확인, 작업 전후 안전 점검 및 작업 중 안전 수칙 준수 철저.',
#  '작업자 안전교육 강화 및 작업장 미끄러짐 방지 시설 설치를 통한 재발 방지 및 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 교육 실시 및 건강 상태 점검 강화, 근로자 건강 상태 확인 철저.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '유리자재 자연파괴에 대한 작업자 안전교육 강화 및 작업 전 유리자재 상태 점검을 통한 위험 요소 사전 제거, 작업 시 보호구 착용 철저, 작업장 내 안전관리 책임자의 안전관리 업무 수행 이행.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '근골격계 질환 예방을 위한 수시 스트레칭 및 올바른 중량물 취급방법 교육 실시와 작업 전 자체 시스템을 통한 근로자 건강상태 파악을 포함한 향후 조치 계획.',
#  '동바리 해체 시 정리 미흡으로 인한 재발 방지를 위해 작업 전 정리 정돈 및 작업 구역 확보를 위한 안전 교육 실시와, 향후 조치 계획 수립 및 이행 여부 확인.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책 및 향후 조치 계획으로 작업 전 안전교육 강화, 작업장 위험 요소 점검, 작업 방법 개선(불안정한 작업 환경에서의 2단 적재 작업 금지), 관련 작업 시 안전 수칙 준수 교육, 사고 전파, 책임 건설사업 관리 기술인 및 안전 전담 감리원 업무 철저 지시, 건설공사 위험 요소 사전 제거 및 철저한 현장 점검, 근로자 안전·보건 교육 철저 지시가 포함됨.',
#  '작업자 숙련도 향상을 위한 교육 실시 및 숙련된 작업자 1인 1조 지정과 함께 작업 전 안전 점검을 통한 재발 방지 현장 계도.',
#  '작업장 정리 정돈 및 장애물 제거를 통해 안전한 작업 환경 조성, 작업 전 안전 교육 강화 및 작업 중 발생 가능한 위험 요소 사전 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '현장 책임자에 대한 관리 감독 철저 및 유사사고 재발 방지를 위한 TBM시간 활용 안전교육 실시. 신호 체계의 명확성을 확보하고, 작업 전 및 작업 중 정기적인 신호 체계 점검을 통해 근로자와 운전자의 오해를 방지하며, 작업 전 안전 교육 및 안전 점검을 통해 작업 환경과 작업 내용에 맞는 신호 체계를 구축하고 숙지해야 함.',
#  '사전 작업 계획 수립 및 작업 방법 교육 강화, 작업 전 안전 점검 철저, 근로자 임의 행동 방지를 위한 교육 실시, 작업장 안전 관리 강화 조치 시행.',
#  '해체 작업 전 조립식 말비계 고정 장치의 고정 확인을 위한 안전교육 강화와 동일한 사고 예방을 위한 시공사 작업자에 대한 철저한 안전교육 실시, 작업지휘자 선정 및 배치, 해체 작업 전 지지대 설치에 대한 조치.',
#  '안전 교육 및 건강 상태 점검 강화, 작업 전 근로자 건강 상태 확인을 통한 재발 방지 대책 수립 및 향후 안전 관리 철저 지시 예정.',
#  '사고사례 전파와 안전교육을 통한 안전관리 철저.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '배관 작업 시 안전 통로 확보 및 위험물질 관리 강화, 작업 전 동료 간 협조 및 안전 확인, 작업 시 안전모 및 개인 보호구 착용 의무화, 배관 내 잔여물 정리 작업 시 추가적인 안전 교육 실시 및 안전 점검 강화와 재발 방지 대책 마련.',
#  '사각블록 적재 시 사전 점검 강화 및 작업자 교육을 통한 안전 의식 고취, 2인 1조 작업 구성, 작업 전 안전 교육 철저, 작업장 위험 요소 점검 등을 통해 재발 방지 대책을 수립하고, 향후 조치 계획으로 주기적인 안전 점검 및 교육 실시를 추진한다.',
#  '작업자 교육 실시 및 작업장 안전 점검 강화.',
#  '사고사례 교육 실시 및 작업 전 안전 점검을 통한 작업자 주의사항 재강조 및 안전 교육 철저를 통한 재발 방지 대책 마련.',
#  '사고 발생 상황 공유 및 안전 교육 강화, 미끄럼 방지 표면 설치 및 A형 사다리 안전 점검을 통해 향후 유사 사고 재발 방지 대책 수립 및 준수 여부 확인.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책 및 향후 조치 계획으로 이동 시 주변 환경 확인 및 위험 요소 확인, 작업 전후 정리정돈의 철저함, 이동간 작업 시 안전거리 확보 및 작업 전후 안전 점검 실시, 작업자 안전 교육 강화 및 TBM 활동 시 작업 내용, 장소, 방법에 대한 교육 실시.',
#  '불안전한 작업 자세 및 동작 예방을 위한 안전 교육 강화 및 작업 시 안전 수칙 준수를 위한 교육 실시. 작업 시 안전 장비 착용 철저 및 작업 공간 확보를 통한 재발 방지 대책 마련.',
#  '현장조사에 따른 안전조치와 향후 조치 계획. 강풍 시 작업 중지 및 작업 전 강풍 예보 확인, 작업 전 작업 환경 점검 강화, 작업자 안전 교육 재강화.',
#  '유압기계 운반 시 안전거리 확보 및 작업구간 내 정리정돈 철저, 긴 결철물 운반 시 보호 장비 착용 및 작업 반경 확보, 작업자 안전 교육 실시를 통한 안전사고 예방 및 향후 조치 계획.',
#  '바닥 결빙으로 인한 미끄럼 사고 예방을 위한 작업 전 습윤 작업, 작업복 착관, 안전모 착용 등 안전수칙 준수 교육 실시와 작업 구역 결빙 방지 조치 (난간 설치, 제설 작업 등)를 위한 향후 조치 계획.',
#  '작업 전 안전교육 및 작업발판 설치/점검 철저, 작업 중 안전모/안전화 착용 의무화, 작업 지휘자 지정 및 안전 관리 감독 강화, 고소 작업 시 안전 수칙 준수 교육 실시.',
#  '말비계 작업 시 안전모 및 안전화 착용 의무화, 작업 전 주변 정리 정돈 실시, 작업 전 안전 교육 실시 및 1m 이상 고소 작업에 대한 수시 점검을 통한 향후 조치 계획.',
#  '사고 원인에 대한 교육 및 안전수칙 준수 강조, 작업 전 동료 간 협력 및 안전 확인 시스템 강화, 고소작업 시 안전고리 착용 및 추락 방지 장비 점검 철저, 작업 전 주변 환경 및 작업 공간 안전 점검, 비계 설치 및 작업 시 안전 관리 책임자 감독 강화.',
#  '작업 전 지지부재 주변 위험 요소 확인 및 정리, 작업 중 하중 증가를 유발할 수 있는 행위 금지, 작업 중 안전 표지판 설치 및 관리 강화, 작업자에게 하중 제한 및 안전 수칙 교육 실시, 작업장 안전 점검 및 관리 강화.',
#  '추락 방지대 설치 및 점검 강화, 작업자 온열 질환 예방을 위한 휴식 및 수분 섭취 관리 철저, 작업자 안전 교육 및 비계 안전 점검을 통한 향후 조치 계획.',
#  '작업 전 안전 교육 실시 및 작업자 부주의 방지를 위한 주의사항 숙지, 작업 현장 정리정돈 및 위험 요소를 제거하는 대책과 향후 조치 계획.',
#  '벌목 작업 전 벌목공 및 장비기사를 대상으로 안전교육을 시행하고, 사고 발생 사례를 전파하며, 안전교육 결과를 보고하는 조치 계획. 작업 시 보호구 착용을 의무화하고, 벌도목 운반 시 안전거리를 확보하며, 작업 전 주변 정리 정돈을 철저히 실시하여 사고 발생 위험을 최소화해야 한다.',
#  '작업 전 위험성 평가 실시 및 옹벽 주변 환경 정리 정돈, 옹벽 하부 침수 방지 조치, 근로자에게 옹벽 작업 시 안전 수칙 교육 실시 및 안전모, 안전화 등 개인 보호 장비 착용 의무화, 작업 감독자 지정 및 상시 감독을 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육 실시 및 작업장 정리정돈에 관한 관리자 관리.',
#  '작업대차 운행 전 자재 고정 상태 확인 및 무게 중심 점검을 위한 작업자 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '휀스 설치 시 풍압을 고려한 설계 및 고정 강도 보강, 강풍 시 작업 중단 및 안전 구역 설정과 함께 작업자 안전 교육 및 2인 1조 작업 실시를 포함한 재발 방지 대책 및 향후 조치 계획.',
#  '안전난간 시설 설치 전 작업 공간 및 철근 위치 확인을 통한 위험 요인 사전 점검, 작업 전 안전 교육 강화, 작업자 개인 보호구 착용 의무화, 작업 공간 주변 정리정돈 철저, 위험물 관리 강화 등 재발 방지 대책 수립 및 향후 조치 계획 실행.',
#  '작업 전 안전교육 강화 및 작업 현장 미끄럼 방지 시설 설치, 작업자 안전 의식 고취 및 주의 분산, 향후 조치 계획으로 작업 환경 개선 및 안전 점검 강화.',
#  '작업 전 안전 교육을 통해 무리한 작업 동작의 위험성을 강조하고, 작업장 정리 정돈을 철저히 시행하며, 개인의 부주의를 방지하기 위한 추가 교육 및 점검을 실시할 것.',
#  '작업대차 운행 전 원형스리브 폐합 절차 준수 및 안전 점검 강화, 작업자 특별안전교육 실시, 대형 자재 운반 시 작업인원 준수 및 작업방법 철저히 준수하도록 교육 철저를 요청하는 조치.',
#  '근로자 안전교육 강화 및 현장 점검을 통한 위험 요인 개선, 동종사고 예방을 위한 교육 실시 및 안전관리 책임자의 감시 활동 강화.',
#  '고소작업대 사용 시 안전 점검 강화, 2인 1조 작업 실시, 작업 시 안전 수칙 준수 교육 및 작업 환경 개선을 통해 재발 방지 대책 마련.',
#  '추락사고 등 안전사고 발생 위험 구간 조치와 작업자 안전교육의 철저함.',
#  '작업 전 바닥 결빙 상태 점검 및 미끄럼 방지 안전조치 강화, 작업 시 미끄럼 방지 장비 (샌드백, 안전화 등) 착용 철저, 그리고 안전관리자 의한 작업장 주기적인 안전 점검 실시.',
#  '사건 발생 시 해당 작업 방식에 대한 안전 교육 강화 및 작업자 안전 점검을 통한 재발 방지, 특히 작업 시 인접 구조물과의 간격 유지 및 작업 전 안전 점검 철저를 통한 향후 조치 계획 수립.',
#  '암석 제거 작업 시 안전 수칙 준수 교육 강화, 작업 전 지반 및 암석 상태 대한 철저한 확인, 작업 시 안전 장비 착용 의무화, 작업 중 위험 요소 발생 시 즉시 작업 중단 및 보고, 작업 전후 지점 안전 점검 실시, 작업자 안전 교육 및 훈련 실시, 관리 감독자의 안전 활동 강화, 시공사에 재발 방지 대책 수립 요청, 작업 환경 개선 및 안전시설 보강 지시가 포함된 안전 관리 방안.',
#  '말비계 설치 시 바닥 확인을 위한 안전교육 실시와 작업 전 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 발생 시 즉각적인 응급조치 및 현장 보존, 사고 원인 분석을 위한 상세 조사 실시, 작업자 안전 교육 강화 (특히 사각지대 인식 및 안전보행 교육), 작업 구역 통제 강화 (경계석 설치 및 안전 표지판 부착), 관련 규정 준수 여부 재검토 및 지침 마련, 향후 유사 사고 방지를 위한 예방 조치 계획 수립 및 시행.',
#  '작업 전 안전 점검 강화 및 안전고리 설치 확인, 작업자 안전 교육 실시, 작업 환경 개선 (작업 발판 높이, 접근 용이성 등) 등을 통해 재발 방지 대책을 수립하고, 안전관리 책임자의 현장 지휘 및 감독을 통해 향후 조치 계획을 수립한다.',
#  '크람쉘 운전석의 안전 점검 강화 및 미끄러운 표면 개선, 이동 중 안전 수칙 준수 교육 실시, 작업 시 관리감독자 및 안전감시단 배치를 통한 감독 강화.',
#  '재발 방지 대책 및 향후 조치 계획의 마련. 특히, 이격거리 미확보의 원인을 철저히 분석하여 유사 사고 재발 방지를 위한 안전 교육 강화, 작업 전 이격거리 확인 절차 준수 교육, 화재 발생 시 신속 대응을 위한 소화 장비 점검 및 비상 연락 체계 구축, 흙막이 시설 주변의 가연성 물질 관리 강화, 작업 구역 내 화재 예방 활동 철저.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지 대책 수립, 작업 중 크레인 샤클 이동 시 주변 환경 확인 및 안전 거리 확보 교육 실시, 그리고 비산 방지 시설물 설치 및 관리 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 방법 개선을 통한 재발 방지 대책 수립 및 안전 교육 철저를 통한 향후 조치 계획 수립.',
#  '전산볼트 제거 및 주변 정리정돈 실시, 작업 전 작업물 주변 정리정돈 철저, 작업 동선 확보 및 정비, 작업자 안전 교육 강화, 작업 전 위험 요인 사전 점검 실시, 관련 규정 준수 및 안전관리 철저, 재발 방지 대책 수립 및 이행 점검.',
#  '신호관리자 및 작업자 교육 철저와 사고 조사 및 작업자 치료조치, 산재조치 등의 완료.',
#  '가설계단 미끄러짐 방지를 위한 안전 교육 실시 및 미끄럼 방지 시설물 설치, 작업 시 주의 집중 철저를 통한 재발 방지 대책 마련.',
#  '작업 전 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 특히, 미끄러운 작업면 및 트랙 주변에 대한 위험성 경고 표시를 하고, 작업 시 안전모 및 안전화 착용을 의무화하며, 작업 전 장비 주변 정리 및 안전 확인을 실시해야 합니다. 또한, 신규 투입 근로자에 대한 특별 안전교육을 실시하고, 작업자 및 관리자의 위험성 평가에 사고 사례를 반영하여, 정기 안전교육 및 초기 투입자 교육에서 사고 사례 공유가 필요합니다.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '끼임방지블럭 사용 의무화 및 사용 교육 실시, 쇠지렛대(빠루) 등 유사 도구 사용 금지, 작업자 경험적 무사고 맹신 방지를 위한 안전 교육 강화, 작업 전 안전 점검 철저 및 관리감독자 배치 철저, 그리고 재발 방지 대책 수립 후 안전관리 철저.',
#  '작업발판 연결 상태 점검 강화 및 작업 전 안전 점검 실시, 작업자 안전 교육 철저, 작업장 위험 요소 개선 등 재발 방지 대책 및 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 충분한 안전교육 이행과 안전거리 확보.',
#  '작업 전 안전교육 강화 및 작업자 부주의 방지를 위한 교육 실시, 작업장 정리정돈 및 위험 요소 제거, 개인 보호구 착용 의무화 및 점검을 통한 향후 조치 계획.',
#  '전원 공급 상태에서 톱날 교체 작업 시 특별 안전 교육 실시, 전원 공급 장치 작동 전/후 확인 절차 수립 및 교육, 작업 전 안전 점검 철저, 작업자 부주의 방지 교육 강화, 전원 공급 장치 누르기 전 확인 절차 명확화 및 반복 교육, 2인 1조 작업 시 작업반장 확인, 위험성 평가 재실시 및 개선 조치.',
#  '고용주는 작업 환경의 온도를 점검하고, 작업 중 무더위로 인한 어지럼증을 예방하기 위해 충분한 휴식시간을 제공해야 합니다. 또한, 작업복은 통풍이 잘 되는 소재를 사용하고, 작업 중에는 수분 섭취를 충분히 하여 어지럼증을 예방해야 합니다. 작업 전후 근로자 건강 상태 확인 및 안전 교육 철저를 통해 재발 방지 대책을 마련해야 합니다.',
#  '흙막이 가시설 설치 시, 도르레 및 로프의 강도 검증 강화, 로프의 정기적인 안전 점검 및 교체 시스템 구축, 작업반장 보호를 위한 안전 매트 설치 및 주변 안전 거리 확보, 작업 전 안전 교육을 통해 위험 요소를 숙지, 작업 중 안전 수칙 준수 및 비상 연락 체계 구축, 동일/유사 사고 재발방지 교육 실시, 책임 및 안전전담 건설사업관리기술인 업무 철저 지시',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '양중 작업 전 굴착기 운전원의 숙련도 향상을 위한 추가 교육 실시, 굴착기 운전 시 작업 구역 내 안전 거리 확보 및 주변 작업자 통제 강화, 작업 전후 안전 점검 철저, 안전관리자 책임 강화 및 현장 관리 감독 철저.',
#  '작업 전 안전 점검 강화 및 백호 하차 시 미끄럼 방지 교육 실시, 작업장 주변 정리 정돈 철저, 그리고 미숙련자 작업 시 관리자 감독 강화.',
#  '균열 발생 시 즉시 작업 중단 및 안전 교육 실시, 작업 환경 안전 점검 강화, 철근 다발 운반 시 안전 수칙 준수 교육, 유사 사고 재발 방지를 위한 현장 점검 및 보고서 작성.',
#  '그라인더 사용 전 안전 교육 실시 및 작업 숙지, 작업물 상태 확인, 안전모 및 보호 장비 착용, 작업장 정리정돈을 통한 재발 방지 대책 마련 및 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '해체 작업 시 해체 순서 준수 및 안전 교육 철저를 통한 재발 방지 및 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전의식 고취를 위한 안전교육 강화 및 작업 환경 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책 및 향후 조치 계획으로 미장 작업 시 공구 보관 장소 및 방법 교육 실시, 작업 전 공구 위치 확인 및 작업자 예고 강화, 작업장 주변 정리정돈 철저히 시행, 작업자들에게 안전 수칙 준수의 중요성 강조, 작업 전 점검 실시 및 작업 환경 확인, 안전 교육 실시 및 작업자 정기교육 시 사고사례 전파가 포함됨.',
#  '경사 지형에 대한 사전 위험성 평가 실시 및 안전표지 설치, 작업 전 지반 정비 및 다짐 작업 실시, 덤프트럭 운전원에게 성토구간 안전 운행 교육 실시, 작업 구역 내 장비 접근 제한 및 안전 표지판 설치 등 안전 관리 강화 조치.',
#  '사고 원인에 따른 안전 교육 강화 및 별도 고정 설치 또는 안전 조치 준수를 위한 작업 지시, 추가적인 안전시설물 설치를 통한 추락 방지 조치 계획 수립 및 현장 안전관리 철저.',
#  '작업 현장 내 통행 차량 관리 강화 및 작업자들의 통행 차량 주의 교육을 통해 재발 방지 대책을 수립하고, 향후 유사 사고 발생 시 즉각적인 안전 교육 실시.',
#  '사고 원인에 따른 재발 방지 대책 및 향후 조치 계획 수립 필요. 정면 시인 및 작업 전 안전 점검 강화, 위험물 취급 교육 실시, 작업 전 안전 점검 및 주변 환경 확인 철저 등의 조치 계획 수립.',
#  '상하 동시 작업 금지 지시 및 관리 감독 강화, 작업 전 안전 교육 철저를 통한 재발 방지 대책 마련 및 향후 조치 계획 수립.',
#  '고소작업 시 안전난간 설치 및 작업자 안전고리 체결을 필히 시행하고, 작업 전 현장 안전점검을 강화하여 위험 요소를 사전에 제거해야 합니다. 또한, 고소작업 시 안전관리 책임자의 감독을 철저히 하고, 작업자에게 안전 수칙을 지속적으로 교육하여 안전 의식을 고취해야 합니다.',
#  '재발 방지 대책으로 작업 전 안전 점검 강화 및 비계자재 인양 시 안전 장비 착용 의무화, 작업 중 주의 집중 및 균형 유지 교육 실시, 작업 환경 위험 요소를 제거하고 작업 중인 자재의 안전을 확보하는 등 향후 조치 계획 수립.',
#  '공구 관리 강화 및 작업 전 안전 교육 철저를 통한 재발 방지 대책 수립 및 향후 조치 계획 마련.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 위험성 평가를 통해 세굴 가능성을 확인하고, 작업자 접근 통제 및 안전 구역 설정, 작업 지휘자의 안전 점검 강화 등 재발 방지 대책을 수립하며, 향후 조치 계획으로 사고 조사 및 안전 교육 실시를 진행한다.',
#  '작업순서 준수 및 안전사고 예방을 위한 교육 훈련 강화와 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 시작 전 TBM을 통해 해체 작업 시 착지 시 안전 교육을 실시하고, A형 사다리 사용 시 안전 수칙 준수 및 착지 자세 교육을 실시하여 작업방법순서 미숙지로 인한 사고가 발생하지 않도록 하는 재해 예방 조치.',
#  '작업 전 작업 공간 정리 및 확보, 작업 시 안전 장비 착용 점검, 자재 운반 시 안정적인 자세 유지 교육, 작업자 안전 교육 강화 및 작업 관리감독 철저를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 전 안전 점검 강화 및 작업자 안전 교육 실시를 통해 재발 방지 대책 마련 및 향후 조치 계획으로 작업 전 점검 및 작업 환경 위험 요소를 제거, 작업자 안전 교육 강화 및 통신 수단 확보, 작업 중에는 반드시 안전 수칙 준수하도록 교육 실시.',
#  '작업 전 안전교육의 강화 및 소통 채널 확립(무전기, 시각 신호 등)을 통한 정확한 정보 전달 체계 구축, 작업 전 위험성 평가를 통한 안전 조치 및 작업 지침 준수, 크레인 신호수 및 작업자 재해사례 전파를 통한 안전 의식 고취, 작업 지시 시 확인 철저 및 작업 중단 시 즉시 조치 등 안전관리감독의 철저함.',
#  '작업대 고정 상태 점검 및 안전 교육 강화, 작업자 부주의 방지를 위한 안전 수칙 준수 교육, 그리고 사고 발생 시 응급처치 교육 실시를 포함한 조치 계획.',
#  '작업 전 위험 요소를 사전에 확인하고, 작업 반경 내 건설 자재 위험성에 대한 근로자 교육을 강화하며, 작업 지휘자의 지시에 따른 작업 관리 및 안전모 착용 등 안전 수칙 준수를 통해 재발 방지.',
#  '유압 작업기 안전 교육 강화 및 작업 전 유압호스 압력 확인 절차 준수 철저, 작업 전 주변 확인 및 작업자 유무 점검을 위한 수시 교육 실시, 안전표지 부착 및 작업 공간 확보를 통한 안전사고 예방.',
#  '경사로 작업 시 안전 표지판 설치 및 작업자 안전 교육 강화, 추가적인 안전 수칙 마련을 통해 재발 방지 대책 수립 및 향후 조치 계획을 시행.',
#  '작업 전 안전 교육 강화 및 작업장 미끄러운 지형 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 근로자 건강상태 확인, 작업장 위험요소 점검 및 안전교육 강화, 사고 발생 시 신속한 응급 처치 및 이송 체계 구축을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 전 개인 보호구 작용 점검 및 시설물 점검, 관리 감독자 상주 하에 작업, 근로자 임의 작업 금지, 관리 감독자 및 근로자 특별 교육 실시, 현장 정리 정돈 및 근로자 보호구 착용 점검, CM단 및 원도급사 현장 수시 점검 실시.',
#  '경사로 주변 정리 정돈 철저 및 작업 시 주의력 결여 방지를 위한 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지 대책 및 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 점검 강화 및 작업 발판의 견고한 설치, 작업자 안전 교육 실시, 작업 지시 및 감독 강화, 안전표지판 설치 및 안전관리 책임자 지정.',
#  '호이스트 작업 시 작업자 안전 교육 강화 및 작업 지시사항 준수 철저, 작업 전 스트레칭 실시, 작업 중 집중력 향상을 위한 교육 실시 및 작업 중 지속적인 안전 점검.',
#  '작업 전 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 해당 작업 현장에 안전대 고리 체결을 위한 부착 설비 설치를 의무화하고, 안전대 고리 체결 교육을 실시하며, 작업자는 안전장비를 필히 착용하도록 해야 함. 또한, 작업 전 위험 요인을 지속적으로 확인하고, 2인 1조 작업으로 작업 진행 상황을 점검하는 조치.',
#  '작업 속도 조절 및 이동 시 발 디딤 확인 철저, 작업 전 스트레칭 실시, 관리감독자 확인 후 작업, TBM 및 정기교육을 통한 사고 교육 및 위험성 평가 예방 대책 이행 확인과 유사사고 재발 방지 대책 제출 통보.',
#  '작업 시 미끄러운 바닥 및 위험 요소 사전 확인, 안전화 착용 의무화, 작업 시 이동구간 안전 확보 및 주의, 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 점검 강화 및 작업 중 전방 주시 철저를 통한 사고 예방, 유사 공종 발생 시 작업자 주의사항 재교육 실시, 작업 안전 교육 및 훈련 실시.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '이동 시 주변 환경 및 위험 요소 사전 확인, 위험 요소 제거 및 안전 교육 강화, 작업 시 안전 장비 착용 의무화 및 근로자 안전 교육 철저를 통한 재발 방지 대책.',
#  '작업 전후 근로자 건강 체크 및 안전 보호구 착용 철저, 작업 중 넘어짐 예방을 위한 주의 교육 실시, 유로폼 자재 이동 시 안전거리 확보 및 신호 활용, 현장 안전 관리자 점검 강화 및 사고 발생 시 즉각적인 응급 처치 및 후속 조치 계획 수립.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 환경 정리 정돈 및 미끄럼 방지 시설 설치, 작업자 중심 유지를 위한 안전 교육 실시 및 작업 중 안전 수칙 준수 철저.',
#  '미끄러운 헌치 부분에 대한 사전 점검 및 주의 표지 설치, 미끄럼 방지 신호판 설치, 안전벨트 착용 철저 및 작업 중 안전 확보, 작업 전 안전 교육 강화 및 현장 정리 철저를 통한 재발 방지 대책 수립.',
#  '상세 안전 점검 및 작업 전 안전 교육 강화, 작업 중 낙하물 방지 장비 착용 의무화, 작업 전 위험 요소를 파악하고 작업 공간 확보 및 안전표지 설치를 통한 재발 방지 대책 마련.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '볼트 체결 작업 시 안전 교육 강화 및 작업 전 안전 점검 철저를 통한 재발 방지, 작업자 부주의로 인한 사고 예방을 위한 주의 교육 실시, 현장 관리 감독 강화 포함한 조치 계획.',
#  '회전날 커버 사용 시 안전 수칙 준수 및 작업 중 톱날 청소 시 추가 안전 교육 실시를 통한 재발 방지 계획 수립 및 이행 점검.',
#  '재해사례 전파 안전교육 실시와 동일작업시 신호수 및 관리감독자 배치, 충돌위험구간 방호조치 후 작업 시행.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전관리 교육 철저를 통한 재발 방지 대책 수립, 작업 전 절곡기 사용 교육 강화, 작업 중 부주의 방지를 위한 주의보수 및 안전 수칙 준수 교육, 작업 중 발생하는 끼임 사고 발생 시 즉시 작업 중지 및 비상 정지 장치 활용 유도, 재해자 산재 보험 처리 검토.',
#  '차수 그라우팅 인발(록드 해체) 작업 시 과도한 힘의 사용으로 인한 안전사고 예방을 위한 특별안전교육 실시 및 작업자 안전의식 고취, 작업 절차 준수 교육 강화, 작업 강도 및 속도 제한, 작업 중 안전 점검 강화가 포함된 재발 방지 대책과 사고 조사 결과에 따른 안전 관리 시스템 개선 및 향후 조치 계획 수립.',
#  '작업 전 안전 교육 강화 및 작업 지시 사항 준수 교육 실시를 통한 재발 방지 대책 수립 및 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 시스템 비계 및 주변 환경 점검을 통해 변형된 부분 확인 및 보수 후 작업 실시, 안전대 착용 의무 준수 및 무리한 작업 지양 등 재발 방지 대책 마련과 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '계단 이용 시 난간대를 확실히 잡고 천천히 이동하도록 교육 강화 및 작업 전 주변 환경 점검을 통해 미끄러운 부분 확인 및 개선, 작업자에게 계단 이용 시 주의사항 재강조 및 관련 교육 실시, 작업 전 안전 점검을 통한 위험 요소 제거 및 관리감독자 점검 강화 필요.',
#  '높이 인지 교육 강화 및 낙하물 방지 조치 마련, 작업자 안전 교육 철저를 통해 유사사고 재발 방지.',
#  '작업자 안전 교육 강화 및 작업 환경 위험 요소 점검을 통한 재발 방지, 안전모 및 안전화 등 보호구 착용 의무화, 작업 전 충분한 보고 및 확인 절차 실시를 통한 향후 조치 계획.',
#  '고속절단기 운반 시 안전 수칙 준수 교육 강화 및 전원 차단 의무화 철저 시행, 고속절단기 운반 시 작업 전 안전 점검 및 작업 구역 설정, 작업자 안전 교육 및 훈련 실시, 안전관리 책임자의 현장 감독 강화 및 사고 발생 시 즉각적인 안전 조치 및 보고 체계 구축.',
#  '작업장 안전시설 점검 강화 및 안전 교육 실시를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전 관리 교육 철저를 통한 향후 조치 계획. 작업 구획 설정 및 출입 통제, 고소작업차 안전 점검 강화, 숏크리트 배관 내부 막힘으로 인한 압력 및 진동 발생 방지를 위한 작업 계획 수립 및 변경, 앵글의 고정 상태 점검 및 보강, 작업자 안전모 착용 의무화 및 2인 1조 작업 실시, 동종 재발 방지를 위한 안전교육 실시.',
#  '재발 방지 대책과 향후 조치 계획으로 작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 연결 통로 지붕의 노후 상태를 주기적으로 점검하고, 노후된 지붕은 즉시 보수 또는 교체해야 함. 작업 전 안전 교육을 강화하여 작업자의 안전 의식을 고취하고, 작업 전 위험 요소에 대한 사전 점검을 철저히 실시해야 함. 또한, 작업 중에는 안전모, 안전화 등 보호 장비를 반드시 착용하도록 하고, 작업 중 발생할 수 있는 위험 요소를 사전에 파악하여 예방 조치를 취해야 함.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '컷팅기 작동 전 안전 점검을 통한 위험 요인 제거 및 작업 전 안전 교육 철저를 통해 향후 재발 방지 조치 계획 수립.',
#  '근로자 건강상태 유지와 적정한 휴식시간 준수 교육, 작업 전후 건강상태 파악 및 수시 점검, 폭염경보나 주의보 시 규정 준수 옥외 순찰 강화, 식염포도당, 얼린 생수, 아이스크림 지급 및 적절한 휴식 부여를 통한 재발 방지 대책.',
#  '재해자 작업 내용 확인 및 안전 교육 강화, 작업 중 안전 확인 절차 준수 교육 실시, 작업 전 안전 점검 실시 및 작업 환경 개선, 유사 사고 재발 방지를 위한 현장 안전 관리 감독 강화.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전모 착용 관리 강화 및 작업 전 안전 교육 철저를 통한 향후 조치 계획.',
#  '안전교육을 통한 미끄러짐 방지 교육 강화 및 작업 전 바닥 정리, 미끄럼 방지 장비 사용 등을 통해 재발 방지 조치 계획을 수립하고, 즉각적인 보고 체계를 확립하는 조치.',
#  '이동 중 시동 확인 및 안전 수칙 준수 교육 강화, 작업 현장 안전 점검 강화, 작업자 교육 이수 확인 및 안전 관리 철저를 통한 향후 조치 계획.',
#  '작업 전 주변 환경 및 위험 요소 확인 의무화, 작업 구역 주변 정리 정돈 철저, 깨진 타일 등 위험 자재 보관 시 주의사항 교육 실시, 개인 보호구(장갑 등) 착용 철저 및 안전 점검 강화.',
#  '개인보호구 착용 의무화 및 안전거리 확보 교육 실시와 함께, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '시스템 비계 발판의 정기적인 점검 및 유지보수 강화, 안전 점검 지침 준수 교육 실시, 작업 전 발판 상태 확인 절차 강화 및 작업자 안전 의식 고취를 통한 향후 조치 계획.',
#  '이동식 사다리 사용 시 2인 1조 작업 준수 및 안전 교육 강화, 사다리 하단 고정 점검 철저, 작업 전 안전 점검 실시, 2인 1조 작업 미준수로 인한 추락 사고 예방 대책 마련.',
#  '안전 고리 의무 착용 점검 강화 및 작업 전 안전교육 실시를 통한 재발 방지 대책 수립, 안전 점검 강화 및 관련 지침 재교육, 향후 유사 사고 예방을 위한 작업 절차 및 방법 교육 실시.',
#  '말비계 설치 위치 점검 강화 및 작업 공간 정리 철저를 통한 유사사고 재발 방지, 작업자 안전 교육 재강화 및 현장 관리 감독 강화.',
#  '작업 전 안전교육 강화 및 작업 환경 위험 요소 점검을 통한 재발 방지 대책 마련, 안전의식 고취를 위한 자체 교육 실시.',
#  '작업 전 지면 정리 및 위험물 제거, 작업 시 안전거리 확보, 작업 시 안전모 착용 등의 재발 방지 대책 수립 및 근로자 안전 교육 실시.',
#  '작업자의 건강 상태를 지속적으로 확인하고, 응급 상황 발생 시 신속하게 대처할 수 있도록 비상 연락 체계 구축 및 응급처치 교육 실시, 작업 전 건강 상태 점검 및 스트레칭 등을 통해 작업 환경에 적합한 상태 유지, 그리고 향후 유사 사고 예방을 위한 정기적인 건강 검진 실시.',
#  '재발 방지 및 향후 조치 계획으로 단기적 대책으로는 작업 전 안전 점검 강화 및 작업 반경 준수 사항 재확인, 장기적 대책으로는 고소 작업차 운전 기사 교육 강화 및 작업 반경 관련 안전 수칙 준수 철저, 작업 반경 관련 안전 관리 감독 강화가 필요하다.',
#  '동바리 돌출부위 노출 위험 해소를 위한 작업 전 위험 요소 점검 강화 및 작업 구역 격리, 관련 종사자 대상 특별 안전 교육 실시 (안전 장갑 착용 및 위험 요소 인지 교육), 작업 전 위험 요소 확인 및 제거를 통한 안전교육 철저.',
#  '해체 전 강재 손실 여부 확인 절차 수립 및 시행, 강재 해체 작업 시 안전거리 확보, 작업자 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전벨트 착용 의무화 및 안전난간 설치확보 등 작업 전 안전 점검 강화, 작업 중 안전 수칙 준수 교육 실시, 추락 방지 시설물 설치 및 관리 감독 강화 등 재발 방지 대책 마련.',
#  '바닥 설비 슬래브 위치 정보 제공 및 위험 요소 사전 점검을 위한 교육 실시, 작업 전 작업구간 안전 확인 및 작업자 안전 수칙 준수 철저.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 시 강풍 대비 안전 수칙 준수 교육을 실시하고, 작업 구역 내 바람의 영향력을 고려한 작업 계획을 수립해야 한다. 또한, 작업 시에는 개인 보호구 착용을 철저히 하고, 작업 구역 내 안전 표지판을 설치하여 추가적인 부딪힘 사고를 예방해야 하며, 향후 인양 작업 시에는 바람의 영향을 최소화하기 위한 방지 조치를 마련하고, 작업자들에게 해당 사항을 반복적으로 교육하여 재발 방지될 수 있도록 해야 한다.',
#  '작업 전 위험물질 확인 및 작업공구 취급 시 안전 수칙 준수 철저요청, 작업자 안전 교육 강화, 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '바닥 상태 점검 및 사다리 안정성 확보를 위한 작업 전 안전교육 강화와 작업 환경 점검을 통한 재발 방지 대책 수립, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사다리 이동 시 2인 1조 작업 실시 및 안전 점검 강화, 단독 작업 금지 교육 실시, 작업 전 안전 점검 및 작업 환경 개선을 통한 재발 방지 대책.',
#  '작업 전 TBM을 통해 주요 작업 및 위험 요인을 파악하고 근로자 특별안전교육을 통해 주요 위험 작업 상황을 재교육하며, 현장 안전관리를 철저히 하고 지도하는 조치 계획.',
#  '작업 전 굴착기 운전원에 대한 안전 교육 강화 및 작업 구역 내 안전 표지판 설치를 통해 운전원의 주의 분산을 최소화하고, 작업 지휘자의 현장 안전 관리 감독을 철저히 실시하여 재발 방지 대책을 마련하며, 향후 조치로 안전 교육 주기 재확인 및 안전 점검 강화 실시.',
#  '작업 전 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 현장 정리 정돈 및 위험물 제거 철저, 그라인더 작업 전 말려들어갈 수 있는 물질 제거 절차 준수 교육 실시, 관리감독자의 현장 안전관리 활동 강화 및 작업 전 안전 점검 실시, 그리고 근로자 안전의식 고취를 위한 교육 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '추가적인 건강 검진 실시, 작업 환경 내 유해 요인 점검 및 개선, 작업자 건강 상태 모니터링 강화, 관련 질병 예방 교육 실시.',
#  '계단 작업 시 미끄럼 방지 시설 설치 및 작업 전 계단 상태 점검을 통해 안전 확보, 작업자 미끄럼 방지 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 원인에 따른 안전 교육 강화 및 작업장 위험요소 점검을 통해 재발 방지, 굴착 작업 시 넘어짐 방지 교육 실시 및 안전모, 안전화 등 보호구 착용 의무화, 작업 전 지형 파악 및 위험 요소를 인지하고 작업 진행, 현장 관리감독 철저 및 안전 점검 강화.',
#  '안전교육 실시 및 작업 구역 안전 점검 강화, 작업자 주의 분산 및 안전 장비 착용 철저를 통한 재발 방지.',
#  '미끄러운 곳 방지 패드 설치 의무 준수 여부 확인 및 즉시 보수 조치, 관련 안전 교육 강화 및 작업장 위험 요소 점검 실시를 통한 재발 방지.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '계단실 이동 시 안전사고 예방을 위한 교육 실시 및 안전 표지판 설치, 안전모 착용 의무화, 작업 시 주의 강화 등의 조치.',
#  '사다리 작업 시 비대칭 세움 금지 및 아웃트리거 전개 의무화 교육 강화, 개인 보호구 착용 의무 준수 교육 실시, 2인 1조 작업 지시 및 작업 전 안전 점검 철저를 통한 재발 방지 대책 마련.',
#  '덮개 제거 및 안전 구역 설정, 작업 시 안전 속도 준수 등 안전 교육 강화 및 작업 현장 정리정돈 철저를 통한 재발 방지 대책.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 작업 전 전원 차단 의무 교육 실시, 작업 중 안전 수칙 준수 교육 실시, 작업 구역 내 안전모 착용 의무화, 유사 재해 재발 방지를 위한 시공 관계자 및 근로자 특별안전교육 시행.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업차량 이동 시 안전벨트 착용 의무화 및 정지 시 안전 점검 철저 지시와 작업자 안전의식 함양을 위한 특별안전보건교육 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '공구류 사용에 대한 안전교육 및 시공사항 교육과 관리 감독 강화.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '신호체계 교육 및 훈련 강화, 하역운반 작업 시 신호체계 준수 철저, 하역운반 작업 전 안전 점검 실시, 작업자별 신호체계 숙지 및 반복 훈련을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 전 가설재의 안전 상태 점검 및 제거를 위한 절차 마련, 작업 시 상하 동시 작업 금지 및 작업 지휘자의 철저한 통제, 작업자 안전 교육 및 훈련 실시, 작업 계획서에 따른 안전 관리 강화.',
#  '샌드위치 구조물 해체 시 시스템 동바리 사용 금지 및 작업 전 안전 교육 강화, 작업 순서 및 안전 수칙 준수 교육 실시, 작업 시 관리자 상주 및 안전 지도 강화, 유사 재해 방지를 위한 작업 방법 개선 및 교육 실시.',
#  '안전대 착용 의무 준수 및 작업발판 고정 점검 강화, 안전교육 실시를 통한 향후 조치 계획.',
#  '가시설 철거 시 안전벨트 착용 및 안전지대 확보 교육과 유사사례에 대한 안전교육 실시. 작업 전 안전 점검 및 작업자 교육 철저를 통한 향후 조치 계획.',
#  '계단실 작업 시 미끄럼 방지 대책 마련 및 작업자 안전 교육 강화, 작업 전 충분한 준비 시간 확보를 통한 작업 안전 확보.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 교육 강화 및 흡연 금지 구역 설정, 화재 예방 시설 점검, 감리자 및 시공사에 대한 안전 관리 감독 철저 지시.',
#  '지하매설물 위치 확인 작업 전 사전 점검 및 안전 교육 강화, 작업 계획 협의 및 확인 철저를 통한 재발 방지 대책 마련.',
#  '시스템 동바리 해체 시 상부부터 순차적으로 진행하고, 작업 전 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지 대책 이행 여부를 수시로 확인하는 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '안전 수칙 준수 교육 강화 및 작업 전 안전 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지 대책 수립, 작업 중 안전 수칙 준수 교육, 그리고 작업장 주변 정리정돈 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 속도 준수 및 안전 속도 교육 실시와 함께, 작업 전 안전 점검을 통한 재발 방지 대책 마련 및 향후 조치 계획 수립.',
#  '근로자 안전 교육을 통해 바닥의 미끄러운 표면 인지 및 주의 교육을 실시하고, 작업 구역 주변 정리 정돈을 통해 유사 사고 발생을 예방하며, 향후 조치 계획으로 관련 장비의 안전 점검 및 유지 보수 점검 실시.',
#  '노면의 결빙구간 제거를 위한 작업 전 사전 점검 강화 및 작업장 내 결빙 방지 시설 설치를 통해 유사 재발 방지, 또한 안전 교육을 통해 근로자의 주의를 환기하고 재해 발생 시 신속한 대처를 위한 조치 계획 수립.',
#  '단차부 위치에 대한 교육 강화 및 안전표지판 설치를 통한 재발 방지 대책과 향후 조치 계획.',
#  '벽면 청소 작업 시 말비계 사용, 불안전한 작업자세로 무리한 작업 금지, 근로자의 불안전한 행동 방지를 위한 점검활동 강화, 작업자 안전교육 실시 및 관리 철저.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 작업 전 덕트 고정 상태를 반드시 확인하고, 작업 시 안전대 착용을 필수로 지정하며, 고소 작업 시 안전대 부착설비 설치 및 고정설치 방법 교육 실시, 관리감독자 및 신호수의 현장 이탈 시 작업 중지 지시.',
#  '작업자 부주의로 인한 넘어짐 사고 발생 시, 작업자에게 대한 안전 교육 강화 및 작업장 내 위험 요소를 지속적으로 점검하여 재발 방지 및 안전관리 교육 철저를 통한 향후 조치 계획 수립 필요.',
#  '작업자 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '2층 접근 금지 구역 내 작업자 접근 제한을 위한 교육 강화 및 안전요원의 배치, 작업 전 안전 점검을 통한 위험 요소 제거, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 지반 상태 점검 강화, 양중 작업 시 지반 안정성 확보 위한 사전 조치 및 작업 시 추가 점검 실시, 작업자 안전 교육 철저 및 안전장비 착용 의무화, 작업 전/중/후 정리 정돈 실시, 전담 관리 감독자 지시 사항 준수.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 정해진 이동 통로 준수 및 시간 단축을 위한 위험 요소 인식 개선 교육 실시, 작업 시 안전모 및 안전화 착용, 추락 방지 위험표지 가시적 표시 및 작업 전후 현장 정리 정돈의 철저함.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 건강검진 강화 및 심혈관 질환 위험군 작업자에 대한 집중 관리, 응급 상황 발생 시 신속한 대처를 위한 응급 의료 시스템 구축 등 재발 방지 대책 마련 및 향후 조치 계획 수립 필요.',
#  '와이어 샤클 점검 및 관리 절차 강화, 작업 중 크레인 회전 금지, 작업자 및 장비 조종원 교육 실시, 작업 전 안전 매뉴얼 숙지 및 점검 철저를 통한 재발 방지 및 향후 조치 계획.',
#  '화재 예방 절차 준수 및 소화 장비 점검 강화, 인화물질 관리 철저, 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 위험 예지 훈련 및 근로자 위험 요소 상기 교육 실시, 작업장 주변 환경 점검 강화 및 안전 작업 수칙 준수를 위한 교육 실시.',
#  '케이블타이 사용 작업 시 컷터칼 사용 금지 및 작업 중 안전수칙 준수 교육을 실시하고, 작업 전 컷터칼 사용에 대한 위험성을 강조하여 안전사고를 예방하며, 작업자 안전 의식 고취 및 안전교육 철저를 지시한다.',
#  '작업자 안전 수칙 준수 철저, 작업자 부주의 방지 교육 실시, 작업 구역 위험 요소 점검 강화, 작업 전 안전 교육 철저 및 작업자 책임 강화.',
#  '안전 교육 강화 및 작업 전 위험 요소 점검을 통해 작업자 부주의로 인한 사고 재발을 방지하고, 작업 중 안전 수칙 준수를 위한 교육을 실시하여 향후 조치 계획을 수립한다.',
#  '전원 차단 절차 준수 및 안전 교육 강화, 작업 전 장비 점검 철저, 작업 시 안전 수칙 준수, 작업 환경 정리 정돈 실시, 안전 점검 강화 실시.',
#  '작업 공간 확보 및 작업 전 안전 교육 강화, 특히 좁은 공간에서의 유로폼 설치 시 주의사항 교육을 실시하고, 안전 장비 착용을 철저히 지시하며, 현장 관리자의 감독을 강화하여 유사 사고 재발을 방지해야 합니다.',
#  '철선 절단 및 후속 고정 시 근로자의 부주의를 방지하기 위한 작업 전 안전교육 강화, 작업장 위험 요소 점검을 통한 재발 방지, 그리고 실천적 위험성 평가 강화 및 장비기사 및 신호수 특별 안전교육 철저를 통한 향후 조치 계획.',
#  '원인 불명으로 인한 스파크 발생에 대비하여, 작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 및 향후 조치 계획으로 기술적 대책으로 모래 부설 부위 주변 토사 안정화 방안 마련 및 보강, 관리적 대책으로 굴착 작업 전 지반 조사 및 안정성 평가 실시, 작업 중에는 주변 토사 유실 위험을 감시하고 즉시 작업 중단, 교육적 대책으로 작업자에게 굴착 작업 시 주의사항 및 위험 요소 교육 실시, 사고사례 작성 및 TBM 시 근로자 공유 및 교육 실시.',
#  '작업 시 거푸집 주변 정리 시 안전유의 당부와 작업자 등의 안전관리에 소홀하지 않도록 안전교육 실시.',
#  '말비계 설치 기준 준수 교육 및 작업 자세 교육을 통한 재발 방지 대책 수립과 작업 중 안전거리 확보를 통한 사고 예방, 알폼 해체 시 안전장비 사용 및 작업 방법 교육 실시를 통한 무리한 작업 지양 및 향후 동일한 작업 시 관리감독자 및 안전관리자를 통한 집중관리와 해당 팀원 특별안전보건교육을 통한 안전작업수칙 및 안전의식 함양.',
# ...
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '살수기 엔진 가동 중 호스 요동으로 인한 작업자 안전 수칙 준수 및 관리감독자에 대한 사고의 위험성 및 사고 예방교육 철저.',
#  '작업 전 스트레칭 실시 및 작업 중간 충분한 휴식 부여, 근로자 사전 지병 여부 확인 철저를 포함한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업대 정기 점검 및 유지 보수 강화, 작업 전 안전 점검 실시, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전 지지대 설치 의무화 및 안전 점검 강화, 작업자 안전 교육 집중 실시를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '소음 노출 예방을 위한 개인보청기 지급 및 착용, 작업 시간 제한, 소음 감소를 위한 장비 사용, 작업자 대상 소음 노출 예방 교육 실시, 작업 후 청력 검사 실시 및 결과에 따른 작업 조정 등 재발 방지 대책 수립 및 안전관리 교육 철저.',
#  '해체 자재 정리정돈 철저히 시행하고, 작업 전 주변 장애물 인지 교육을 강화하여 유사 사고 재발 방지 대책을 수립 및 이행.',
#  '현장 정리정돈 철저, 낙하물 방지 장비 설치, 작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '철물 운반 작업 시 작업 전 안전 점검 강화 및 작업자들의 안전 수칙 준수 철저를 통한 재발 방지 대책과, 작업 환경 개선 및 안전 교육 철저를 통한 향후 조치 계획.',
#  '중량자재 이동 시 허가 절차 준수 및 작업자 안전 교육 강화, 작업장 위험 요소 점검 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획의 통합으로 작업 전 안전 교육 강화, 작업장 위험 요소 점검 및 위험성 평가 실시, 신호수와 크레인 조종수 간 신호 통신 정확성 확보를 위한 교육 실시, 크레인 훅 하강 시 근로자 안전 확보를 위한 안전 수칙 준수 교육 실시, 작업 방법의 적정성 확인, 무리한 작업 근절을 위한 절차 및 계획 수립, TBM 및 위험성 평가 전파 교육을 통한 유사사례 교육 실시 등이 포함된 종합적 대책 수립.',
#  '재발 방지 대책으로 작업 전 안전 점검 강화 및 작업자별 재해자 인지 교육 실시, 기중기 운전원에게 재해자 위치 파악 및 안전 교육 강화, 작업장 내 안전 표지판 설치 및 위험 구역 설정, 관련 법규 및 안전 수칙 준수 교육 실시, 사고 조사 결과에 따른 개선 대책 이행 및 근로자 전파 교육 실시가 이루어짐.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '전화 통화 금지 및 양손 사용 철저 관리, 작업 전 안전 교육 강화, 작업장 위험 요소 점검 실시, 작업 중 집중력 유도를 위한 교육 실시.',
#  '상부 및 하부 작업 시 안전표시판 설치, 작업 공간 확보, 작업자 간 협업 및 통제 강화, 시스템 동바리 작업 전 안전교육 실시, 작업 현장 위험요소 점검을 통한 재발 방지 대책 수립 및 교육 철저.',
#  '공구 사용법 교육 강화 및 숙련도 향상을 위한 추가 훈련 실시와 함께 작업 전 점검 의무화 및 작업자 안전 의식 고취를 통한 향후 조치 계획.',
#  '장비 이동 시 신호체계 강화 및 운전원, 유도원 간 교육 실시, 신호체계 준수 철저 지시, 작업 전 안전 점검 강화, 재발 방지 대책 수립 및 향후 유사 사고 방지 교육 실시 예정.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 발생 시 즉각적인 재해자 구조 및 응급처치를 실시하고, 사고 원인 분석을 통해 와이어로프 관리 및 사용에 대한 지침을 재검토합니다. 또한, 작업 환경 내 와이어로프 관련 물체에 대한 안전 점검을 강화하고, 근로자에게 와이어로프 관련 위험 요소 교육을 실시하여 재발 방지 대책을 수립합니다. 특히, 안전모의 비래 및 충격 방지를 위한 보호 장비 착용 의무를 강조하고, 안전 교육을 통해 유사 사고 발생 가능성을 최소화할 계획입니다.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책으로 작업 전 앵글 해체 작업 시 안전 거리 확보 교육 실시, 작업 시 관리감독자의 상주 및 작업 지시, 관련 공종 공사참여자에게 즉시 사례 전파를 통한 안전관리 의식 환기 및 관리 철저 당부가 포함된 향후 조치 계획 수립.',
#  '작업 전 지반 상태 확인 및 말비계의 기울기 측정 교육을 강화하고, 드레인 커버의 안전 점검 절차를 명확히 하는 기술적 대책을 마련하며, 동종 재해 예방을 위한 안전 교육을 실시하여 근로자의 안전 의식을 고취한다.',
#  '작업 전 주변 환경 확인 및 안전거리 확보, 펌프카 붐대 슈트 압력 관리 철저, 안전관리 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전 점검 강화 및 계단 주변 위험 요소 제거, 추락 방지 안전모 착용 의무화, 계단 작업 시 안전 교육 실시, 관련 작업 지시사항 명확화 및 작업자 교육, 관련 사고 재발 방지 교육 자료 제작 및 교육 실시, 해당 계단 작업 구역 위험 요소 관리 강화 등 향후 계획.',
#  '작업 전 안전 교육 강화 및 슬라브 작업 시 주의사항 교육 철저를 통한 재발 방지와 작업 시 안전모 및 안전화 착용을 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획. 유공발판 정기 점검 및 유지보수 계획 수립, 유공발판 설치 시 안전하게 고정하는 방법 교육, 작업 전 주변 환경 확인 및 위험 요소 제거, 개인보호구 착용 철저, 2인1조 작업 실시, 비상 연락 체계 구축 및 훈련 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '철근 작업 시 안전 교육 강화 및 작업 전 위험 요소 점검을 통해 재발 방지하고, 안전관리 교육을 철저히 실시하여 향후 조치 계획을 수립한다.',
#  '철근 절단기 사용 시 안전 교육 강화 및 숙련된 작업자 배치를 통해 작업 부주의로 인한 사고를 예방하고, 위험 작업 시 집중력을 높이는 안전 관리 교육을 실시하여 재발 방지 및 향후 조치 계획 수립.',
#  '작업 전 안전교육 강화 및 작업 중 보호구 착용 관리 감독 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '텍스 캐링 작업 시 안전 점검 강화 및 보호 장비 착용 의무화, 작업 전 위험 요소를 사전에 파악하고 안전 교육 실시, 관련 작업 시 보호 장비 착용 철저히 준수.',
#  '바퀴형 이동식 비계의 정확한 사용법 교육 및 안전 점검을 포함한 작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업발판의 정기적인 정리정돈 및 안전 점검을 실시하고, 작업자들에게 안전 수칙 준수를 강조하여 재발 방지 대책을 수립한다.',
#  '발판 상태 점검 강화 및 작업 전 안전 교육 철저를 통한 재발 방지 및 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '반복 작업으로 인한 집중력 저하 방지를 위한 작업 휴식 시간 보장, 작업장 주변 정리 정돈을 통한 위험 요소 제거, 작업 전 안전 점검 강화 및 작업자 주의 집중 유도, 철근 작업 시 안전모 착용 의무화 및 안전모 착용 교육 실시, 작업 중 안전 수칙 준수 및 작업자 주의 집중 유도, 향후 유사 재해 방지를 위한 작업자 안전 교육 강화 및 현장 점검 실시.',
#  '작업 관련 안전 교육의 중요성을 관리자에게 주지시키고, 해체 작업 전후에 근로자에게 철저한 안전 교육을 실시하여 동일 사고의 재발을 방지하는 조치 계획.',
#  '작업 전 안전 발판 설치 및 점검 강화, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 TBM을 통해 주요 작업 및 위험 요인을 파악하고 근로자 특별안전교육을 통해 주요 위험 작업 상황을 재교육하며, 현장 안전관리를 철저히 하고 지도하는 조치 계획.',
#  '작업자 이동 시 안전 유의 및 관리 감독 철저와 작업 환경 위험 요소 점검을 통한 재발방지 교육 실시, 피아노선 점검 및 유지보수 강화, 작업 시 안전모 착용 의무화, 지하층 접근 시 안전 교육 실시.',
#  '작업 전 안전교육의 철저한 실시 및 작업 계획에 대한 사전 협의, 위험물저장탱크 작업 시 안전고리 체결 방법 교육 강화, 작업 부위 하단 추락방지망 설치 확인, 작업자 안전모 및 안전화 착용 점검, 고소작업 시 개인보호구 착용 관리감독 강화 및 안전관리규정 준수 교육 실시.',
#  '작업 전 현장 정리정돈 철저히 실시하고, 이동 시 안전표지판 설치 및 주변 위험 요소 제거를 통해 재발 방지하며, 작업자 대상 안전 교육을 강화하여 향후 유사 사고 발생을 예방한다.',
#  '목장갑 착용 의무화 및 착용 교육 실시, 작업 전 안전 점검 강화, 작업자 부주의 방지를 위한 안전 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 주변정리정돈 상태 확인 및 사고 재발방지 교육 실시를 통한 재발 방지 대책과 사업주체(시공자)에게의 작업 전 주변정리정돈 상태 확인 및 사고 재발방지 교육 지도가 포함된 향후 조치 계획.',
#  '지반 불균일로 인한 넘어짐 사고 발생에 대한 재발 방지 대책으로, 지반 보강 작업 실시 및 작업 전 지반 상태 점검을 통해 안전한 작업 환경 조성, 추가적인 안전 교육 실시를 통해 작업자 경각심 고취.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책 및 향후 조치 계획으로 가해 차량의 전방 주시 철저 교육 실시, 도로 주행 시 안전 수칙 준수 교육 강화, 위험 구역 표지판 설치 및 안내 방송 실시, 사고 발생 시 신속한 현장 보수 및 안전 확보 조치, 관련 법규 준수 및 안전 관리 감독 강화.',
#  '작업자 부주의 개선을 위한 안전 교육 강화 및 마대걸이 작업 시 안전벨트 착용 의무화, 작업 전 작업 환경 점검, 작업 감독 강화, 비상 연락 체계 구축 등 향후 조치 계획 수립.',
#  '습한 환경에서의 작업 시 추가적인 안전 교육 실시, 작업 전 사다리 발판의 마찰력 점검 및 미끄럼 방지 조치, 작업 전 주변 환경 점검을 통한 위험 요소 제거, 작업 중 집중력 향상을 위한 휴식 시간 확보, 작업장 내 안전 표지판 설치 및 안전 수칙 준수, 고소 작업 시 안전모 및 안전대 착용 의무화, 안전 관리자 교육 강화 및 재발 방지 대책 수립.',
#  '개인 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자들의 안전 수칙 준수 및 비계 주변 환경 점검 강화 조치, 향후 유사 사고 예방을 위한 안전 교육 실시 필요.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '시스템 설치 및 해체팀 안전교육 실시와 건축관계자에게 안전수칙 정기교육을 통한 사고사례 전파 및 안전교육 이행 여부 확인.',
#  '안전교육 강화 및 고리 체결 관리 철저, 작업 전 안전점검 강화, 작업자 안전 의식 고취 및 안전 수칙 준수 지도.',
#  '뒷걸음질 금지 교육 실시 및 작업 구역 정리정돈 철저, 작업 전 안전 점검 강화, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '절단 작업 시 보호 장비 착용 의무화, 작업 전 주변 정리정돈 및 위험 요소 제거, 절단 작업 시 안전 거리 확보를 위한 교육 실시, 작업자 안전 의식 고취를 위한 지속적인 안전 교육 및 훈련 시행을 통한 재발 방지 대책 및 향후 안전교육과 관리감독 강화.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업 환경 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사다리 표면 미끄럼 방지 조치 (미끄럼 방지 매트 설치 등) 시행, 작업 전 사다리 점검 및 미끄럼 방지 상태 확인, 작업자 안전 교육 강화 및 작업 시 안전 수칙 준수 철저.',
#  '재발 방지 대책으로 작업 완료 후 안전 고리 재체결 절차 준수, 무게 중심 상실 방지를 위한 작업 환경 점검 강화, 작업자 안전 교육 철저 및 작업 시 안전 수칙 준수, 유사 사고 재발 방지 대책 제출 및 향후 조치 계획 수립.',
#  '계단 미끄럼 방지를 위한 계단 바닥 청소 및 방수 조치, 미끄럼 방지 매트 설치, 작업자 안전교육 강화 및 작업 시 주의환기 실시.',
#  '지하 매설물 확인 및 안전 점검 강화, 흙막이 시설 설치 전 지반 조사 및 안정성 평가 실시, 작업 전 위험성 평가를 통해 잠재적 위험 요인 파악 및 안전대책 수립, 작업자 안전 교육 및 훈련 실시, 흙막이 시설 설치 시 안전 관리 책임자 지정 및 감독 강화, 정기적인 안전 점검 및 유지 보수 실시.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책 및 향후 조치 계획으로 철근콘크리트공사 안전수칙 및 작업순서 숙지 확인, 근로자 안전교육 실시, 현장 내 이동로 확보를 위한 자재 정리, 개인 안전보호구 착용 철저가 포함됨.',
#  '재발 방지 대책으로 작업 구간 주변 정리 정돈 및 작업자 안전 의식 고취, 후면 주형보 인지 훈련 실시, 작업 전후 안전 점검 강화, 작업자별 위험 요소 교육 및 훈련 실시, 향후 조치 계획으로 현장 안전 점검 실시 및 관련 사례 전파.',
#  '작업 전 습격 및 작업장 내 미끄럼 방지 장비 설치를 통한 안전사고 예방, 작업자 안전 교육 강화 및 위험 요소 점검을 통한 재발 방지 대책 마련.',
#  '안전교육 실시 및 지도감독 철저와 작업 중 균형 유지 교육, 작업 시 안전화 착용 등 안전수칙 준수의 필요성.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '철근 가공 작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전 관리 교육 철저를 통한 향후 조치 계획.',
#  '안전관리 강화로 숏크리트 시공 전 흙막이 설치 및 유지보수 철저, 용출수 관리 시스템 점검 강화, 작업자 안전 교육 철저 및 숏크리트 시공 시 품질 관리 강화, 향후 조치 계획으로 유사 사고 재발 방지를 위한 기술적 개선 및 관리 감독 강화.',
#  '장애물 확인 및 주변 환경 인지 교육 강화와 함께 작업 전 안전 점검을 통한 재발 방지 대책 수립.',
#  '작업자 안전교육 강화 및 작업발판 고정 철저 및 미끄럼방지테이프 추가 설치와 현장 지도감독 강화를 통한 재발 방지 대책.',
#  '작업전 TBM 및 작업 관련 교육 강화를 통한 안전 교육 등 작업 전 TBM 활동 강화.',
#  '사고 원인에 따른 안전 교육 강화 및 작업 전 위험 요소 점검을 통해 재발 방지 대책을 수립하고, 향후 조치 계획으로 작업자 안전교육 및 톤백마대 사용 시 인양고리 위치 확인 및 주변 정리정돈 철저히 시행하며, 위험 작업 공종에 대한 특별 교육 실시 및 전 직원 대상 안전보건 교육을 실시하여 사고 재발 방지한다.',
#  '그라인더 사용 전 작업 방향 확인 및 안전 교육 강화, 작업 지시사항 준수 철저, 작업 전 안전 점검 실시, 그리고 관리감독자의 현장 안전관리 활동 강화 및 안전 교육 실시를 통해 향후 재발 방지 대책 수립.',
#  '작업 전 주변 확인 및 작업구간 정리 정돈 작업 시 조치사항 확인과 정기 안전 점검을 통한 재발 방지 대책.',
#  '작업 전 안전교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 재발 방지를 위한 안전교육 강화 및 작업 전 안전 점검 실시, 안전모 및 턱끈 착용 의무화 철저, 전방 주시 습관 개선을 위한 교육 실시 및 작업 현장 안전 수칙 준수 강조.',
#  '덕트 설치 작업 시 발 헛대기 방지를 위한 안전 교육 실시 및 작업 공간 주변 정리 정돈, 안전표지판 설치, 관리감독자 배치, 안전모 및 안전화 착용 의무화, 해당 공종 근로자 특별 교육 실시, 안전통로 확보 및 관리 감독자 상주, 산업재해조사표 제출 및 산재보험 처리 계획.',
#  '작업자 안전교육 실시와 작업장 위험요소 점검을 통한 재발 방지 대책 및 향후 작업 전 안전 교육 철저를 통한 조치 계획.',
#  '위험성평가 실시 및 작업 공간 확보, 작업자 공구 조작 숙련도 향상을 위한 교육 및 훈련을 강화하고, 작업 전 안전 점검을 철저히 시행하여 재발 방지 대책을 마련해야 함.',
#  '작업 전 주변 환경 점검 및 위험물 제거, 작업 전 안전교육 철저, 작업 중 주의 집중을 통한 재발 방지 대책 마련 및 향후 조치 계획 수립.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 전원 차단 절차 준수 및 활선감지기, 절연 보호구 등 개인 보호구 착용 철저를 통한 재발 방지 대책 및 사고자 통원치료 완료에 따른 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업발판 고정 상태 점검 강화 및 작업 전 안전 교육 실시, 작업자 안전 의식 고취를 위한 지속적인 교육 및 훈련 실시, 그리고 재발 방지를 위한 작업 절차 준수 및 감독 강화.',
#  '사고 재발 방지를 위한 재해 원인 분석 및 관리적, 기술적, 교육적 대책 수립, 작업 전 계단 안전 점검 실시 및 미비한 점 조치, 작업 중지 조치, 근로자의 미흡한 작업 지시 및 위험작업 거부권 통한 안전조치 후 작업 실시 완료, 작업 전 근로자 안전교육 철저 및 재해 발생 시 즉시 보고 체계 구축.',
#  '빔 고정 강도 강화 및 체결 시 안전 수칙 준수 교육, 작업 전 빔의 상태 점검 및 안전 수평 확인, 작업자 간 협업 및 수신호 정확한 실시, 작업 중 발생할 수 있는 위험 요소를 예측하고 예방하는 교육 실시, 해당 작업구역 관리자 교육 실시.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책 및 향후 조치 계획으로 작업 전 안전교육 강화, 작업장 위험 요소 점검을 통한 재발 방지, 철근 밴딩기 사용 시 작업 방법 교육 실시, 사고사례 전파 및 재발방지 대책 교육 실시, 철근 밴딩기 작동 전 작업자 주의사항 숙지, 안전 점검 및 위험 요소 개선, 작업 지휘자의 감독 강화, 근로자 정기 교육 시 안전 수칙 준수 및 위험 요인 인지 교육 실시.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '고소 작업 전 안전 점검 강화, 작업 전 안전 교육 실시, 작업 중 안전 수칙 준수, 작업 환경 점검을 통한 위험 요소 제거, 작업 중 안전벨트 착용 의무화.',
#  '고소작업대 승하강 발판 관리 교육 강화 및 정기 점검, 작업자 안전 교육 철저 및 불안전한 행동 개선을 위한 교육 실시, 작업장 미끄럼 방지 조치 시행을 통한 재발 방지 대책 마련.',
#  '해당 작업 현장의 위험성 평가를 통해 난간대 시공 불량으로 인한 추락 위험을 사전에 파악하고, 작업 전 안전시설물 점검을 강화하여 유사 사고 재발을 방지해야 한다. 또한, 작업자에게 해당 부위 접근 금지 및 안전 교육을 철저히 실시하여 안전의식을 고취해야 한다.',
#  '자상 방지용 장갑 착용 의무화 및 작업 전 안전교육 강화, 작업장 위험 요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재발 방지 대책으로 작업 시 주의 의무 강화, 발을 헛디딜 위험 지역 안전 표지판 설치, 작업 중 안전 거리 확보 교육 실시, 개인 보호구 착용을 철저히 시행하는 것이 포함된 향후 조치 계획 수립 필요.',
#  '전체 작업자 대상 소통 강화 교육 실시 및 적재 작업 시 동시 다발 작업 금지, 작업 전 안전 점검 실시 철저.',
#  '작업 중 전도에 대한 방지 대책 강화 및 전도 방지 버팀대 점검 강화, 유사 사고 발생 시 근로자 교육 실시 및 작업 전 안전 점검 철저.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '실족 방지 발판 설치 및 위험구간 통행 금지, 작업 전 안전 점검 강화, 근로자 대상 비상 상황 대처 교육 실시 및 재발 방지 대책 시행 및 안전 관리 철저.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '인양 고리 및 관련 장비의 정기적인 점검 및 관리 철저, 용접부 상태 확인 및 보강, 작업 전 안전 교육 강화 (특히 고리 및 연결 부위 점검), 작업 지휘자 지정 및 상주, 위험 작업 시 접근 통제 및 안전 관리 철저, 작업 후 안전 점검 실시 등 재발 방지 대책 수립 및 시행.',
#  '작업장 정리정돈 철저함 및 작업자 안전 교육 강화, 작업 자세 점검을 통한 재발 방지 및 향후 조치 계획 수립.',
#  '현장 정리정돈 실시요령 교육 강화 및 작업장 주변 자재 정리정돈 철저히 실시, 아차사고 발생 시 즉시 안전점검 실시 및 관련자 교육 실시.',
#  '단부 안전난간대 설치 및 고정 철저, 시스템비계 상부 작업 시 안전벨트 착용 철저, 작업 전 안전교육 강화, 작업 환경 위험요소 점검 실시, 안전모 및 안전화 등 개인보호구 착용 의무화, 불안전한 행동 금지 및 작업 절차 준수, 사고 발생 시 즉시 보고 및 시정 조치, 정기적인 안전 점검 및 교육 실시를 통한 재발 방지 대책 마련.',
#  '작업 공간 내 공구 및 장비의 정해진 위치에 보관하고, 작업 전 점검을 통해 위험 요소 제거 및 작업 전 안전 교육을 실시하여 재발 방지 조치.',
#  '지붕판넬 꺾임 방지를 위한 사전 점검 강화 및 작업 전 안전 교육 철저를 통한 재발 방지 대책 마련.',
#  '크레인 작업 시 추락 방지 안전모 착용 의무화 및 작업 전 와이어로프 추 확인 의무화, 작업자 안전 교육 강화 및 작업장 내 위험 요소 점검을 통한 재발 방지 대책 마련.',
#  '작업자 안전교육 강화 및 함마드릴 사용 시 방호 장비 착용 철저, 작업 전 위험 요소 점검 및 현장 감독관의 안전사고 방지 지도 철저를 통한 향후 조치 계획.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '재해자의 부주의를 방지하기 위해, 작업 전 안전 교육 강화 및 흙막이 시설 설치 시 책임자를 지정하고, 작업 전 꼼꼼한 확인 점검을 실시해야 합니다. 또한, 흙막이 시설의 설치 및 관리에 대한 교육을 통해 작업자의 안전 의식을 고취하고, 되메우기 작업 시 주의사항을 숙지하도록 하여 재발 방지에 만전을 기해야 합니다.',
#  '안전 교육 강화 및 작업 전 안전 점검을 통해 위험 요소 제거와 작업장 내 안전 수칙 준수 교육 실시를 통한 재발 방지 대책 마련, 작업 시 보호 장비 착용 (보안경, 안전모 등) 의무화, 작업 중 불안전한 행동에 대한 경고 및 즉시 작업 중단 조치, 사고 발생 시 응급 처치 및 의료 지원 체계 구축.',
#  '가공용 목재 고정 선반 사용 의무화 교육 실시, 작업 전 안전 점검을 통한 위험 요소 제거, 작업 중에는 항상 방호 장비 착용 철저, 현장 감독관의 지속적인 안전 지도 및 관리 감독 강화.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '해체 작업 전 작업 발판 결속 상태 확인을 위한 안전교육 강화 및 해체 자재 정리 상태 점검을 통한 재발 방지, 작업자 안전교육 철저를 통한 향후 조치 계획.',
#  '사고 발생 지점 주변 작업 중단 및 추가적인 넘어짐 사고 예방을 위한 작업 전 구획 설정 철저, 라바콘 운반 작업 시 안전 표지판 설치 및 작업 구역별 접근 통제, PSRC 양중 작업 시 안전 요원 배치 및 비상 연락 체계 구축, 작업 전 안전 점검 및 작업 계획서 검토, 라바콘 운반 작업에 사용된 장비에 대한 정기적인 점검 및 유지보수 실시, 근로자에게 넘어짐 사고 예방 교육 실시 및 안전모, 안전화 등 개인 보호 장비 착용 의무화.',
#  '작업 전 충분한 휴식 시간 확보 및 근로자 피로도 측정, 작업 시간 단축 및 작업 환경 개선, 근로자 집중력 향상을 위한 교육 실시, 작업 전후 안전 점검 강화.',
#  '작업 전 안전 교육 강화 및 작업장 위험 요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 안전교육 강화 및 작업 현장 바닥면 미끄러짐 방지 대책 마련(미끄럼 방지 매트 설치 등)을 통한 재발 방지 대책 및 향후 조치 계획 수립.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 재발 방지를 위한 관리적 대책으로 작업 전 안전교육 실시, 개인보호구 착용상태 관리 철저, 작업안전수칙 준수와 기술적 대책으로 다리 접었을 때 핸드카 사용 시 안전 확인 절차 마련, 작업장 주변 정리정돈 실시 철저, 그리고 향후 조치 계획으로 핸드카 사용 시 다리 접었을 때 안전 확인 절차 교육 강화가 필요함.',
#  '지반 안정성 평가 강화 및 추가적인 지반 보강 조치 시행, 작업 전 지반 상태 점검을 통한 안전 확보, 관련 작업 시 안전 수칙 준수 교육 실시.',
#  '작업 전 안전 교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '반복 작업 시 작업 전 안전 점검 및 작업 방법 숙지 교육 강화, 위험 요소 인지 교육 및 작업자 안전 의식 고취를 위한 교육 실시, 작업 전 위험 요소 확인 및 통제 절차 준수 강조, 작업 환경 점검 및 개선을 통해 유사 사고 재발 방지.',
#  '우천 시 이동 간 주의 사항 교육 실시와 안전수칙 준수를 통한 공사장 안전사고 재발 방지.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 사전 안전점검 강화 및 작업자 간 원활한 의사소통을 위한 교육 실시, 작업자에게 지게차 작업 시 주의사항 및 안전 수칙 교육 실시, 작업 환경 위험 요소 제거 및 개선, 작업 중에는 항상 안전 수칙 준수하도록 지도.',
#  '가조립물 임의 해체 금지 교육 실시 및 작업 전 철골 구조물 안전 상태 점검을 통한 재발 방지 대책 수립, 안전 관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 원인 조사 및 재발 방지 대책 마련, 작업 전 안전 점검 강화, 비상 연락 체계 구축 및 훈련 실시, 향후 유사 사고 방지를 위한 안전 관리 시스템 개선.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업 전 위험성 평가 실시 및 승인된 작업 절차 준수, 미승인 작업 시 즉시 중단, 작업자 안전 교육 강화, 작업장 안전 점검 실시.',
#  '원인 조사 결과에 따라 추가적인 안전 대책 수립 및 화재 예방 시스템 점검 강화, 데크 플레이트 주변 가연성 물질 제거, 방화벽 설치 및 점검, 소화 장비 비치 및 작동 점검, 작업자 대상 화재 예방 교육 실시.',
#  '잭 서포트 작업 시 안전 교육 강화 및 작업 전 주변 정리 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업자 안전교육 및 안전관리 강화. 작업 시 위험 반경 내 통제 철저. 상하 동시 작업 시 사전 작업절차 수립, 해체 구간 구획 설정 및 감시자 배치, 작업 지휘자 배치, 안전작업계획 수립과 안전교육 실시.',
#  '콘크리트 펌프 작업 시 주변 확인 및 안전 수칙 교육 강화, 작업자 부주의에 대한 주의 설문조사 실시 및 작업 전 안전 점검 강화, 위험물 취급 교육 실시.',
#  '작업 전 미끄러짐 방지 위한 작업면 정리 정돈 철저 및 안전 교육 실시 후, 작업자 안전 교육 실시 결과 확인.',
#  '작업전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '스킬 전원 차단 의무 교육 강화 및 작업 전 안전 점검을 통해 유사 사고 재발 방지. 작업복 보호를 위한 방호복 착용 의무화 및 작업 현장 안전 수칙 준수를 위한 교육 실시.',
#  '재발 방지 및 향후 조치 계획으로 현장 차체 및 자체 사고조사 실시, 본사 차원의 재해 및 사고조사 실시, 재발 방지 대책 전파 및 공유 후 현장 적용 실시.',
#  '작업자 안전교육 철저 및 작업 환경 위험요소 제거를 위한 작업 재실시 및 안전 점검 강화.',
#  '기중기 작업 전 최대 양중하중 관리 준수 교육 실시, 작업 계획서 및 작업 전 안전 점검 강화, 신호수 배치 위치 확인 및 통제 강화, 작업자 안전 교육 철저를 통한 향후 조치 계획.',
#  '사고 원인 조사 결과에 따라, 건물 안전 점검 강화 및 구조물 보강 조치, 작업 전 건물 안전 점검 실시, 작업자 안전 교육 강화, 안전표지 설치 및 위험구역 통제 실시, 작업 지휘자 배치 및 작업 감독 강화, 고소 작업 시 안전장비 착용 및 안전 수칙 준수 철저.',
#  'SRC 내부에서의 석재 절단 작업 중단 및 외부 작업 공간 확보, 작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지, 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '작업장 정리정돈 철저 및 작업 전 안전교육 강화, 미끄럼 방지 시설 점검을 통한 향후 조치 계획.',
#  '안전발판 설치 및 유지보수 강화, 작업자 부주의 방지를 위한 안전교육 실시, 작업 전 안전 점검의 철저한 시행을 통한 재발 방지 계획 수립.',
#  '재해 예방 안전교육 실시와 특이사항 없음.',
#  '이동 통로 확보를 위한 작업 공간 정리 및 안전표지판 설치를 통한 재발 방지 대책 마련, 근로자에게 안전 교육 실시 및 작업 전 주변 환경 확인 철저 시행.',
#  '작업 전 안전교육 강화 및 작업장 위험요소 점검을 통한 재발 방지와 안전관리 교육 철저를 통한 향후 조치 계획.',
#  '사고 원인 분석 및 재발 방지 대책 수립, 안전 교육 강화 및 작업 전 안전 점검 철저, 위험물 취급 시 안전 수칙 준수 교육 실시, 작업장 안전 관리 책임자의 현장 감독 강화, 위험물 관리 지침 준수 및 개인 보호구 착용 철저.',
#  '각도절단기 안전 점검 강화 및 작업자 교육 실시, 방호덮개 작동 상태 확인 철저, 재해 발생 시 응급처치 교육 실시를 통한 향후 조치 계획.']
